# %%
import json
import sys

sys.path.append('../../globalfunction')  # setting path
import globalfunction.vv as vv  # importing
import globalfunction.pp as pp  # importing

import pandas as pd

df_original = vv.quick_data(publish=True,exceptional_nans=['size'])
#df_original = pd.read_csv(vv.LISTING_ENRICHED_FILE)
df_original.head(50)
# Out:
# /media/sf_shared_files/Springboard_III/capstone_prep/globalfunction/vv.py:299: DtypeWarning: Columns (23,25,28,31,40,43,44,47,51,56,59,61,62,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_json1 = pd.read_csv(LISTING_JSON_MODEL_FILE)  # EDIT 29-06-2022: There are bid listings and regular listings. I scrape them seporately and join them here.
# remove duplicates: 16093/41831/36278/36750 ==> 16093/32302/32099/32107
# dataframe length: 16026
# allowing Price to pass with 28 nulls/NANs
# allowing type to pass with 72 nulls/NANs
# allowing bedrooms to pass with 725 nulls/NANs
# allowing bathrooms to pass with 1224 nulls/NANs
# dropping other_key_info because 16025 nulls/NANs is too many
# allowing bullet_points to pass with 1401 nulls/NANs
# allowing hold_type to pass with 5190 nulls/NANs
# allowing virtualTours to pass with 8 nulls/NANs
# allowing rooms to pass with 8 nulls/NANs
# allowing nearestAirports to pass with 8 nulls/NANs
# ...

# %%
import json
with open(vv.WORDCLOUD_FILE) as f:
    raw_json = f.read()
# print("Data type before reconstruction : ", type(raw_audit))
# reconstructing the data as a dictionary
df_words = json.loads(raw_json)
df_words
# Out:
# {'double bedroom': 1.0,
#  'double glazed': 0.9367070253026898,
#  'first floor': 0.6519611397085479,
#  'glazed window': 0.6389472921046908,
#  'reception room': 0.6209309069818023,
#  'ground floor': 0.5505691292684695,
#  'open plan': 0.5502428768215761,
#  'rear garden': 0.5242514318857392,
#  'two bedroom': 0.5206989052417893,
#  'fitted kitchen': 0.44982962372217794,
#  'two double': 0.4424345682592619,
#  'transport link': 0.42463568476763575,
#  'chain free': 0.401653012397593,
#  'one bedroom': 0.39440295802218517,
#  'three bedroom': 0.3709490321177409,
#  'communal garden': 0.37073153048647867,
#  'street parking': 0.3614152106140796,
#  'family bathroom': 0.3462988472413543,
#  'bedroom apartment': 0.33473501051257887,
#  'will': 0.3287899659247444,
#  'walking distance': 0.32153991154933664,
#  'living room': 0.318204886536649,
#  'close': 0.31515986369897775,
#  'service charge': 0.31273109548321615,
#  'central heating': 0.3078010585079388,
# ...

# %%
#df = df_original[['Price','bullet_points','long_description']]
df = df_original[['bullet_points','long_description']]
df
# Out:
#                                                bullet_points  \
# ids
# 111309926  Apartment;Close to public transport;Open Plan ...
# 114491630  Two double bedrooms;Reception;Kitchen;Bathroom...
# 108468728  Top Floor;No Chain;Intercom System;Smart Inter...
# 119759102  Open plan kitchen and reception room;2 Bedroom...
# 117676556  Superb Location;Long Lease;Bright and Airy;72s...
# ...                                                      ...
# 82452681   Three bedrooms;No upper chain;End terrace hous...
# 84705516   Two bedroom house;Prime location;Allocated par...
# 120100592  First Floor Maisonette;Excellent Location;Well...
# 121041542  Three bedroom house;Terraced;14ft kitchen;12ft...
# 120696125  No chain;Sought after location;Semi detached;1...
#
#                                             long_description
# ids
# 111309926  Situated within walking distance to Blackheath...
# 114491630  SUMMARY An Enchanting and lovable ground floor...
# ...

# %%
df['content'] = df['bullet_points'] + df['long_description']
df
# Out:
# /tmp/ipykernel_7322/2274388478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['content'] = df['bullet_points'] + df['long_description']
#                                                bullet_points  \
# ids
# 111309926  Apartment;Close to public transport;Open Plan ...
# 114491630  Two double bedrooms;Reception;Kitchen;Bathroom...
# 108468728  Top Floor;No Chain;Intercom System;Smart Inter...
# 119759102  Open plan kitchen and reception room;2 Bedroom...
# 117676556  Superb Location;Long Lease;Bright and Airy;72s...
# ...                                                      ...
# 82452681   Three bedrooms;No upper chain;End terrace hous...
# 84705516   Two bedroom house;Prime location;Allocated par...
# ...

# %%
i = -1
for each in df_words:
    i += 1
    if i>2:break
    print(each)
    label = 'content__' + each.replace(" ","_")
    df[label] = df["content"].str.contains(each)
df['content'].str.contains('double glazed')
# Out:
# /tmp/ipykernel_7322/2259919333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[label] = df["content"].str.contains(each)
# /tmp/ipykernel_7322/2259919333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[label] = df["content"].str.contains(each)
# double bedroom
# double glazed
# first floor
# /tmp/ipykernel_7322/2259919333.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#                                                bullet_points  \
# ids
# 111309926  Apartment;Close to public transport;Open Plan ...
# 114491630  Two double bedrooms;Reception;Kitchen;Bathroom...
# 108468728  Top Floor;No Chain;Intercom System;Smart Inter...
# 119759102  Open plan kitchen and reception room;2 Bedroom...
# 117676556  Superb Location;Long Lease;Bright and Airy;72s...
# ...                                                      ...
# 82452681   Three bedrooms;No upper chain;End terrace hous...
# 84705516   Two bedroom house;Prime location;Allocated par...
# 120100592  First Floor Maisonette;Excellent Location;Well...
# 121041542  Three bedroom house;Terraced;14ft kitchen;12ft...
# 120696125  No chain;Sought after location;Semi detached;1...
#
#                                             long_description  \
# ids
# 111309926  Situated within walking distance to Blackheath...
# 114491630  SUMMARY An Enchanting and lovable ground floor...
# ...
