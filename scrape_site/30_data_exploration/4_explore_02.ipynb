# %%
import pandas as pd

# Import matplotlib and seaborn libraries to visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# Importing libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
import vv
LISTING_ENRICHED_FILE = vv.LISTING_ENRICHED_FILE
LISTING_BASIC_FILE = vv.LISTING_BASIC_FILE
LISTING_JSONMODEL_FILE = vv.LISTING_JSONMODEL_FILE
LISTING_JSON_META_FILE = vv.LISTING_JSON_META_FILE

LISTING_COMBINED_FILE = vv.LISTING_COMBINED_FILE

# %%
df_list = pd.read_csv(LISTING_BASIC_FILE)
#df1 = df1.drop('Links','Address')
df_list.head()
# Out:
#          ids                                              Links  \
# 0  123171899  https://www.rightmove.co.uk/properties/1231718...
# 1   85461000  https://www.rightmove.co.uk/properties/8546100...
# 2   85174740  https://www.rightmove.co.uk/properties/8517474...
# 3  124007903  https://www.rightmove.co.uk/properties/1240079...
# 4   85614570  https://www.rightmove.co.uk/properties/8561457...
#
#                                        Address  \
# 0                           Springbank, London
# 1            Bullsmoor Way, Waltham Cross, EN8
# 2                       Jervis Avenue, Enfield
# 3                     Leigh Hunt Drive, London
# 4  Grovelands Road, Palmers Green, London, N13
#
#                               Description     Price       version  \
# 0            3 bedroom apartment for sale  475000.0  v0021_220622
# 1       3 bedroom terraced house for sale  375000.0  v0021_220622
# 2  2 bedroom semi-detached house for sale  375000.0  v0021_220622
# 3            2 bedroom apartment for sale  375000.0  v0021_220622
# 4                 1 bedroom flat for sale  375000.0  v0021_220622
#
#                   borough                                   referencing_link  \
# 0  ('Enfield', '5E93950')  https://www.rightmove.co.uk/property-for-sale/...
# 1  ('Enfield', '5E93950')  https://www.rightmove.co.uk/property-for-sale/...
# 2  ('Enfield', '5E93950')  https://www.rightmove.co.uk/property-for-sale/...
# 3  ('Enfield', '5E93950')  https://www.rightmove.co.uk/property-for-sale/...
# 4  ('Enfield', '5E93950')  https://www.rightmove.co.uk/property-for-sale/...
#
#                                             add_info         date_scraped
# 0            Added on 09/05/2022 by haart, Southgate  2022-06-26 20:35:34
# 1  Reduced on 17/03/2022 by Christopher Stokes, C...  2022-06-26 20:35:34
# 2     Added on 25/02/2022 by Cottage Fields, Enfield  2022-06-26 20:35:34
# 3            Added on 17/06/2022 by haart, Southgate  2022-06-26 20:35:35
# 4  Added on 11/06/2022 by Anthony Pepe Estate Age...  2022-06-26 20:35:35

# %%
df_indiv = pd.read_csv(LISTING_ENRICHED_FILE)
df_indiv.head()
# Out:
#            ids       version link  Station_Prox type  bedrooms  bathrooms  \
# 0  123510599.0  v0001_130622   --           0.0  NaN       NaN        NaN
# 1   85572123.0  v0001_130622   --           0.1  NaN       NaN        NaN
# 2   85701084.0  v0001_130622   --           0.2  NaN       NaN        NaN
# 3   80180424.0  v0001_130622   --           0.1  NaN       NaN        NaN
# 4   96572116.0  v0001_130622   --           0.1  NaN       NaN        NaN
#
#   size other_key_info bullet_points station_info hold_type short_description  \
# 0  NaN            NaN           NaN          NaN       NaN               NaN
# 1  NaN            NaN           NaN          NaN       NaN               NaN
# 2  NaN            NaN           NaN          NaN       NaN               NaN
# 3  NaN            NaN           NaN          NaN       NaN               NaN
# 4  NaN            NaN           NaN          NaN       NaN               NaN
#
#   long_description         date_scraped
# 0              NaN  1999-01-01 01:00:00
# 1              NaN  1999-01-01 01:00:00
# 2              NaN  1999-01-01 01:00:00
# 3              NaN  1999-01-01 01:00:00
# 4              NaN  1999-01-01 01:00:00

# %%
df_json = pd.read_csv(LISTING_JSONMODEL_FILE)
df_json['id'] = df_json['id'].astype(int)
df_json.head()
# Out:
# /tmp/ipykernel_6456/694389398.py:1: DtypeWarning: Columns (23,25,26,28,31,32,40,44,47,51,54,56,59,60,61,62,63,64,74,78,79,80,82,83,84,85,86,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_json = pd.read_csv(LISTING_JSONMODEL_FILE)
#           id                                        keyFeatures  \
# 0  124126712  ['QUIET AREA SURROUNDED BY ELMSTEAD &amp; MARV...
# 1  122078540  ['Why Should You Buy Me?', 'Limited to Buyers ...
# 2  123967277  ['Three bedrooms', 'Open plan kitchen diner', ...
# 3  123772928  ['Detached Family House', 'Three Double Bedroo...
# 4   85455351  ['Victorian mid terrace house', 'Conveniently ...
#
#                                               images  \
# 0  [{'url': 'https://media.rightmove.co.uk/18k/17...
# 1  [{'url': 'https://media.rightmove.co.uk/246k/2...
# 2  [{'url': 'https://media.rightmove.co.uk/56k/55...
# 3  [{'url': 'https://media.rightmove.co.uk/10k/92...
# 4  [{'url': 'https://media.rightmove.co.uk/5k/431...
#
#                                           floorplans  \
# 0  [{'url': 'https://media.rightmove.co.uk/18k/17...
# 1  [{'url': 'https://media.rightmove.co.uk/246k/2...
# 2  [{'url': 'https://media.rightmove.co.uk/56k/55...
# 3  [{'url': 'https://media.rightmove.co.uk/10k/92...
# 4  [{'url': 'https://media.rightmove.co.uk/5k/431...
#
#                                         virtualTours  \
# 0                                                 []
# 1  [{'url': 'https://my.matterport.com/show/?m=Qr...
# 2  [{'url': 'https://nichecom.s3.eu-west-1.amazon...
# 3                                                 []
# 4  [{'url': 'https://property-teaser-video.s3.eu-...
#
#                                 industryAffiliations  \
# 0  [{'name': 'Association of Residential Letting ...
# 1  [{'name': 'Association of Residential Letting ...
# 2  [{'name': 'Ombudsman for REsale Estate Agents ...
# 3  [{'name': 'Association of Residential Letting ...
# 4  [{'name': 'Association of Residential Letting ...
#
#                                                rooms nearestAirports  \
# 0                                                 []              []
# 1                                                 []              []
# 2                                                 []              []
# 3  [{'name': 'Ground Floor', 'description': None,...              []
# 4                                                 []              []
#
#                                      nearestStations  showSchoolInfo  ...  \
# 0  [{'name': 'Elmstead Woods Station', 'types': [...            True  ...
# 1  [{'name': 'Ravensbourne Station', 'types': ['N...            True  ...
# 2  [{'name': 'Hayes Station', 'types': ['NATIONAL...            True  ...
# 3  [{'name': 'Hayes Station', 'types': ['NATIONAL...            True  ...
# 4  [{'name': 'Orpington Station', 'types': ['NATI...            True  ...
#
#    sharedOwnership.rentPrice sharedOwnership.rentFrequency  \
# 0                        NaN                 not specified
# 1                        NaN                 not specified
# 2                        NaN                 not specified
# 3                        NaN                 not specified
# 4                        NaN                 not specified
#
#   livingCosts.councilTaxExempt livingCosts.councilTaxIncluded  \
# 0                        False                          False
# 1                        False                          False
# 2                        False                          False
# 3                        False                          False
# 4                        False                          False
#
#   livingCosts.annualGroundRent  livingCosts.groundRentReviewPeriodInYears  \
# 0                          NaN                                        NaN
# 1                          NaN                                        NaN
# 2                          NaN                                        NaN
# 3                          NaN                                        NaN
# 4                          NaN                                        NaN
#
#    livingCosts.groundRentPercentageIncrease livingCosts.annualServiceCharge  \
# 0                                       NaN                             NaN
# 1                                       NaN                             NaN
# 2                                       NaN                             NaN
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
#
#   livingCosts.councilTaxBand  livingCosts.domesticRates
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
# [5 rows x 90 columns]

# %%
df_meta = pd.read_csv(LISTING_JSON_META_FILE)
df_meta['id_copy'] = df_meta['id_copy'].astype(int)
df_meta.head()
# Out:
#      id_copy       version         date_scraped analyticsBranch.agentType  \
# 0  123772928  v0021_220622  2022-06-22 13:41:30                   ea_dual
# 1   85455351  v0021_220622  2022-06-22 13:42:34                  ea_sales
# 2   85566933  v0021_220622  2022-06-22 13:42:43                   ea_dual
# 3  118650851  v0021_220622  2022-06-22 13:42:48                  ea_sales
# 4  120326048  v0021_220622  2022-06-22 13:42:54                   ea_dual
#
#    analyticsBranch.branchId analyticsBranch.branchName  \
# 0                      9274                 Petts Wood
# 1                      4316                 Petts Wood
# 2                     50710             Crystal Palace
# 3                     17465          Mottingham- Sales
# 4                     50710             Crystal Palace
#
#    analyticsBranch.branchPostcode analyticsBranch.brandName  \
# 0                             NaN                  Proctors
# 1                             NaN                       jdm
# 2                             NaN                     Acorn
# 3                             NaN    Cockburn Estate Agents
# 4                             NaN                     Acorn
#
#   analyticsBranch.companyName analyticsBranch.companyTradingName  ...  \
# 0                    Proctors                                NaN  ...
# 1                         jdm                                NaN  ...
# 2                 Acorn Group                        Acorn Group  ...
# 3                    Cockburn                                NaN  ...
# 4                 Acorn Group                        Acorn Group  ...
#
#   analyticsProperty.propertySubType analyticsProperty.propertyType  \
# 0                          Detached                         Houses
# 1                          Terraced                         Houses
# 2                              Flat             Flats / Apartments
# 3                        Maisonette             Flats / Apartments
# 4                              Flat             Flats / Apartments
#
#   analyticsProperty.retirement analyticsProperty.selectedCurrency  \
# 0                        False                                NaN
# 1                        False                                NaN
# 2                        False                                NaN
# 3                        False                                NaN
# 4                        False                                NaN
#
#   analyticsProperty.selectedPrice analyticsProperty.soldSTC  \
# 0                             NaN                     False
# 1                             NaN                      True
# 2                             NaN                     False
# 3                             NaN                      True
# 4                             NaN                      True
#
#   analyticsProperty.videoProvider analyticsProperty.viewType  \
# 0                        No Video                    Current
# 1                   External Link                    Current
# 2                        No Video                    Current
# 3                        No Video                    Current
# 4                        No Video                    Current
#
#                          analyticsProperty.customUri Unnamed: 46
# 0  https://www.rightmove.co.uk/property-for-sale/...         NaN
# 1  https://www.rightmove.co.uk/property-for-sale/...         NaN
# 2  https://www.rightmove.co.uk/property-for-sale/...         NaN
# 3  https://www.rightmove.co.uk/property-for-sale/...         NaN
# 4  https://www.rightmove.co.uk/property-for-sale/...         NaN
#
# [5 rows x 47 columns]

# %%
#df_original = df_list.merge(df_indiv, left_on='ids', right_on='ids', suffixes=('_head', '_indiv'))
#df_original.to_csv(LISTING_COMBINED_FILE, encoding="utf-8", header="true", index=True)

# %%
#df_original['Target'] = df_original['Price'].fillna(0.0).str.replace('[£,]', '').replace('POA', 0.0).astype('float')
HOW = 'left'
df_original = df_list \
    .merge(df_indiv, on='ids', how='inner', suffixes=('_indiv', '_listing')) \
    .merge(df_json, left_on='ids',right_on='id', how=HOW, suffixes=('_comb2', '_model')) \
    .merge(df_meta, left_on='ids',right_on='id_copy', how=HOW, suffixes=('comb3', '_meta'))
#combined_df

df_original.set_index("ids", inplace=True)
df_original = df_original[~df_original.index.duplicated(keep='last')]

# %%
#df_original = df_original.drop(['Links','version_listing','version_indiv','link'], axis=1)
df_original['compass'] = df_original["address.outcode"].str.extract("([a-zA-Z]+)")
df_original['borough_name'] = df_original["borough"].str.extract("'([a-zA-Z]+)'")

# %%
df_original = df_original[['Station_Prox','bedrooms_model','bathrooms_model','compass','borough_name',
                           #'analyticsProperty.propertyType','analyticsProperty.propertySubType',
                           'propertySubType','tenure.tenureType','tenure.yearsRemainingOnLease','address.outcode','address.incode','location.latitude','location.longitude','analyticsProperty.added','analyticsProperty.auctionOnly','analyticsProperty.minSizeFt','analyticsProperty.maxSizeFt','prices.pricePerSqFt','analyticsProperty.ownership','analyticsProperty.preOwned','analyticsProperty.priceQualifier','analyticsProperty.soldSTC','Price']]
df_original.to_csv(LISTING_COMBINED_FILE, encoding="utf-8", header=True, index=True)
df_original
# Out:
#            Station_Prox  bedrooms_model  bathrooms_model compass borough_name  \
# ids
# 123171899           0.6             3.0              2.0       N      Enfield
# 85461000            0.6             3.0              1.0      EN      Enfield
# 85174740            0.4             2.0              1.0      EN      Enfield
# 124007903           0.2             2.0              1.0       N      Enfield
# 85614570            0.2             1.0              1.0       N      Enfield
# ...                 ...             ...              ...     ...          ...
# 96654763            0.4             3.0              1.0      CR       Sutton
# 96654973            0.0             3.0              2.0      SW       Merton
# 96655021            0.2             3.0              2.0      SW   Wandsworth
# 97404863            0.9             1.0              1.0      SM       Sutton
# 97494416            0.3             1.0              1.0      SM       Sutton
#
#                propertySubType tenure.tenureType  \
# ids
# 123171899            Apartment         LEASEHOLD
# 85461000              Terraced               NaN
# 85174740         Semi-Detached          FREEHOLD
# 124007903            Apartment         LEASEHOLD
# 85614570                  Flat         LEASEHOLD
# ...                        ...               ...
# 96654763   Link Detached House          FREEHOLD
# 96654973                  Flat         LEASEHOLD
# 96655021                 House          FREEHOLD
# 97404863             Apartment         LEASEHOLD
# 97494416                  Flat         LEASEHOLD
#
#            tenure.yearsRemainingOnLease address.outcode address.incode  ...  \
# ids                                                                     ...
# 123171899                           NaN             N21            1JH  ...
# 85461000                            NaN             EN8            8HW  ...
# 85174740                            NaN             EN3            6LJ  ...
# 124007903                           NaN             N14            6BZ  ...
# 85614570                            NaN             N13            4RJ  ...
# ...                                 ...             ...            ...  ...
# 96654763                            NaN             CR4            4JB  ...
# 96654973                            NaN            SW19            8LY  ...
# 96655021                            NaN            SW16            6BH  ...
# 97404863                            NaN             SM3            8HH  ...
# 97494416                            NaN             SM2            5GN  ...
#
#           analyticsProperty.added  analyticsProperty.auctionOnly  \
# ids
# 123171899                20220509                          False
# 85461000                 20220607                          False
# 85174740                 20220505                          False
# 124007903                20220617                          False
# 85614570                 20220611                          False
# ...                           ...                            ...
# 96654763                 20220530                          False
# 96654973                 20220530                          False
# 96655021                 20220530                          False
# 97404863                 20200919                          False
# 97494416                 20200921                          False
#
#           analyticsProperty.minSizeFt analyticsProperty.maxSizeFt  \
# ids
# 123171899                         NaN                         NaN
# 85461000                          NaN                         NaN
# 85174740                          NaN                         NaN
# 124007903                         NaN                         NaN
# 85614570                          NaN                         NaN
# ...                               ...                         ...
# 96654763                          NaN                         NaN
# 96654973                          NaN                         NaN
# 96655021                          NaN                         NaN
# 97404863                          NaN                         NaN
# 97494416                          NaN                         NaN
#
#            prices.pricePerSqFt  analyticsProperty.ownership  \
# ids
# 123171899                  NaN         Non-shared ownership
# 85461000                   NaN         Non-shared ownership
# 85174740                   NaN         Non-shared ownership
# 124007903                  NaN         Non-shared ownership
# 85614570                   NaN         Non-shared ownership
# ...                        ...                          ...
# 96654763                   NaN         Non-shared ownership
# 96654973                   NaN         Non-shared ownership
# 96655021                   NaN         Non-shared ownership
# 97404863                   NaN         Non-shared ownership
# 97494416                   NaN         Non-shared ownership
#
#           analyticsProperty.preOwned analyticsProperty.priceQualifier  \
# ids
# 123171899                     Resale                      Offers Over
# 85461000                      Resale                             None
# 85174740                      Resale              Offers in Region of
# 124007903                     Resale                             None
# 85614570                      Resale              Offers in Excess of
# ...                              ...                              ...
# 96654763                      Resale                      Guide Price
# 96654973                      Resale                             None
# 96655021                      Resale                             None
# 97404863                      Resale                             None
# 97494416                      Resale                      Guide Price
#
#           analyticsProperty.soldSTC     Price
# ids
# 123171899                     False  475000.0
# 85461000                      False  375000.0
# 85174740                       True  375000.0
# 124007903                     False  375000.0
# 85614570                      False  375000.0
# ...                             ...       ...
# 96654763                      False  500000.0
# 96654973                      False  650000.0
# 96655021                      False  675000.0
# 97404863                      False  175000.0
# 97494416                      False  120000.0
#
# [10375 rows x 22 columns]

# %%
#df_original['Target'] = df_original['Price'].fillna(0.0)
#df_original.shape

# %%
#df_original = df_original[df_original["Target"] != 'POA']
print(df_original.shape)
df_original.head(5)
# Out:
# (10375, 22)
#            Station_Prox  bedrooms_model  bathrooms_model compass borough_name  \
# ids
# 123171899           0.6             3.0              2.0       N      Enfield
# 85461000            0.6             3.0              1.0      EN      Enfield
# 85174740            0.4             2.0              1.0      EN      Enfield
# 124007903           0.2             2.0              1.0       N      Enfield
# 85614570            0.2             1.0              1.0       N      Enfield
#
#           propertySubType tenure.tenureType  tenure.yearsRemainingOnLease  \
# ids
# 123171899       Apartment         LEASEHOLD                           NaN
# 85461000         Terraced               NaN                           NaN
# 85174740    Semi-Detached          FREEHOLD                           NaN
# 124007903       Apartment         LEASEHOLD                           NaN
# 85614570             Flat         LEASEHOLD                           NaN
#
#           address.outcode address.incode  ... analyticsProperty.added  \
# ids                                       ...
# 123171899             N21            1JH  ...                20220509
# 85461000              EN8            8HW  ...                20220607
# 85174740              EN3            6LJ  ...                20220505
# 124007903             N14            6BZ  ...                20220617
# 85614570              N13            4RJ  ...                20220611
#
#            analyticsProperty.auctionOnly analyticsProperty.minSizeFt  \
# ids
# 123171899                          False                         NaN
# 85461000                           False                         NaN
# 85174740                           False                         NaN
# 124007903                          False                         NaN
# 85614570                           False                         NaN
#
#           analyticsProperty.maxSizeFt  prices.pricePerSqFt  \
# ids
# 123171899                         NaN                  NaN
# 85461000                          NaN                  NaN
# 85174740                          NaN                  NaN
# 124007903                         NaN                  NaN
# 85614570                          NaN                  NaN
#
#            analyticsProperty.ownership analyticsProperty.preOwned  \
# ids
# 123171899         Non-shared ownership                     Resale
# 85461000          Non-shared ownership                     Resale
# 85174740          Non-shared ownership                     Resale
# 124007903         Non-shared ownership                     Resale
# 85614570          Non-shared ownership                     Resale
#
#           analyticsProperty.priceQualifier analyticsProperty.soldSTC     Price
# ids
# 123171899                      Offers Over                     False  475000.0
# 85461000                              None                     False  375000.0
# 85174740               Offers in Region of                      True  375000.0
# 124007903                             None                     False  375000.0
# 85614570               Offers in Excess of                     False  375000.0
#
# [5 rows x 22 columns]

# %%
#df_original['compass'] = df_original["postcode"].str[0:2]
#df_original['type'] = df_original["Description"].str.extract("(house|apartment|flat|maisonette)")
#df_original['sq_ft'] = df_original["size"].str.extract("(\d*) sq. ft.")
#df_original['hold_type2'] = df_original["hold_type"].str.replace("Tenure:","").str.strip()

df_original
# Out:
#            Station_Prox  bedrooms_model  bathrooms_model compass borough_name  \
# ids
# 123171899           0.6             3.0              2.0       N      Enfield
# 85461000            0.6             3.0              1.0      EN      Enfield
# 85174740            0.4             2.0              1.0      EN      Enfield
# 124007903           0.2             2.0              1.0       N      Enfield
# 85614570            0.2             1.0              1.0       N      Enfield
# ...                 ...             ...              ...     ...          ...
# 96654763            0.4             3.0              1.0      CR       Sutton
# 96654973            0.0             3.0              2.0      SW       Merton
# 96655021            0.2             3.0              2.0      SW   Wandsworth
# 97404863            0.9             1.0              1.0      SM       Sutton
# 97494416            0.3             1.0              1.0      SM       Sutton
#
#                propertySubType tenure.tenureType  \
# ids
# 123171899            Apartment         LEASEHOLD
# 85461000              Terraced               NaN
# 85174740         Semi-Detached          FREEHOLD
# 124007903            Apartment         LEASEHOLD
# 85614570                  Flat         LEASEHOLD
# ...                        ...               ...
# 96654763   Link Detached House          FREEHOLD
# 96654973                  Flat         LEASEHOLD
# 96655021                 House          FREEHOLD
# 97404863             Apartment         LEASEHOLD
# 97494416                  Flat         LEASEHOLD
#
#            tenure.yearsRemainingOnLease address.outcode address.incode  ...  \
# ids                                                                     ...
# 123171899                           NaN             N21            1JH  ...
# 85461000                            NaN             EN8            8HW  ...
# 85174740                            NaN             EN3            6LJ  ...
# 124007903                           NaN             N14            6BZ  ...
# 85614570                            NaN             N13            4RJ  ...
# ...                                 ...             ...            ...  ...
# 96654763                            NaN             CR4            4JB  ...
# 96654973                            NaN            SW19            8LY  ...
# 96655021                            NaN            SW16            6BH  ...
# 97404863                            NaN             SM3            8HH  ...
# 97494416                            NaN             SM2            5GN  ...
#
#           analyticsProperty.added  analyticsProperty.auctionOnly  \
# ids
# 123171899                20220509                          False
# 85461000                 20220607                          False
# 85174740                 20220505                          False
# 124007903                20220617                          False
# 85614570                 20220611                          False
# ...                           ...                            ...
# 96654763                 20220530                          False
# 96654973                 20220530                          False
# 96655021                 20220530                          False
# 97404863                 20200919                          False
# 97494416                 20200921                          False
#
#           analyticsProperty.minSizeFt analyticsProperty.maxSizeFt  \
# ids
# 123171899                         NaN                         NaN
# 85461000                          NaN                         NaN
# 85174740                          NaN                         NaN
# 124007903                         NaN                         NaN
# 85614570                          NaN                         NaN
# ...                               ...                         ...
# 96654763                          NaN                         NaN
# 96654973                          NaN                         NaN
# 96655021                          NaN                         NaN
# 97404863                          NaN                         NaN
# 97494416                          NaN                         NaN
#
#            prices.pricePerSqFt  analyticsProperty.ownership  \
# ids
# 123171899                  NaN         Non-shared ownership
# 85461000                   NaN         Non-shared ownership
# 85174740                   NaN         Non-shared ownership
# 124007903                  NaN         Non-shared ownership
# 85614570                   NaN         Non-shared ownership
# ...                        ...                          ...
# 96654763                   NaN         Non-shared ownership
# 96654973                   NaN         Non-shared ownership
# 96655021                   NaN         Non-shared ownership
# 97404863                   NaN         Non-shared ownership
# 97494416                   NaN         Non-shared ownership
#
#           analyticsProperty.preOwned analyticsProperty.priceQualifier  \
# ids
# 123171899                     Resale                      Offers Over
# 85461000                      Resale                             None
# 85174740                      Resale              Offers in Region of
# 124007903                     Resale                             None
# 85614570                      Resale              Offers in Excess of
# ...                              ...                              ...
# 96654763                      Resale                      Guide Price
# 96654973                      Resale                             None
# 96655021                      Resale                             None
# 97404863                      Resale                             None
# 97494416                      Resale                      Guide Price
#
#           analyticsProperty.soldSTC     Price
# ids
# 123171899                     False  475000.0
# 85461000                      False  375000.0
# 85174740                       True  375000.0
# 124007903                     False  375000.0
# 85614570                      False  375000.0
# ...                             ...       ...
# 96654763                      False  500000.0
# 96654973                      False  650000.0
# 96655021                      False  675000.0
# 97404863                      False  175000.0
# 97494416                      False  120000.0
#
# [10375 rows x 22 columns]

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10375 entries, 123171899 to 97494416
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Station_Prox                      10375 non-null  float64
#  1   bedrooms_model                    7669 non-null   float64
#  2   bathrooms_model                   7455 non-null   float64
#  3   compass                           8005 non-null   object
#  4   borough_name                      9249 non-null   object
#  5   propertySubType                   8002 non-null   object
#  6   tenure.tenureType                 7467 non-null   object
#  7   tenure.yearsRemainingOnLease      494 non-null    float64
#  8   address.outcode                   8005 non-null   object
#  9   address.incode                    8005 non-null   object
#  10  location.latitude                 8005 non-null   object
#  11  location.longitude                8005 non-null   float64
#  12  analyticsProperty.added           7990 non-null   object
#  13  analyticsProperty.auctionOnly     7990 non-null   object
#  14  analyticsProperty.minSizeFt       1255 non-null   float64
#  15  analyticsProperty.maxSizeFt       1255 non-null   float64
#  16  prices.pricePerSqFt               1261 non-null   object
#  17  analyticsProperty.ownership       7989 non-null   object
#  18  analyticsProperty.preOwned        7990 non-null   object
#  19  analyticsProperty.priceQualifier  7990 non-null   object
#  20  analyticsProperty.soldSTC         7989 non-null   object
#  21  Price                             10375 non-null  object
# dtypes: float64(7), object(15)
# memory usage: 1.8+ MB

# %%
#df_original["sq_ft"] = pd.to_numeric(df_original["sq_ft"], 'coerce').fillna(-1).astype(int)
#df_original["Target"] = pd.to_numeric(df_original["Target"], 'coerce').fillna(-1).astype(int)
for each in ['analyticsProperty.added','prices.pricePerSqFt']:
    df_original[each] = pd.to_numeric(df_original[each], 'coerce').fillna(-1).astype(int)
df_original.info()

for each in ['analyticsProperty.auctionOnly']:
    df_original[each] = pd.to_numeric(df_original[each], 'coerce').fillna(-1).astype(bool)
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10375 entries, 123171899 to 97494416
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Station_Prox                      10375 non-null  float64
#  1   bedrooms_model                    7669 non-null   float64
#  2   bathrooms_model                   7455 non-null   float64
#  3   compass                           8005 non-null   object
#  4   borough_name                      9249 non-null   object
#  5   propertySubType                   8002 non-null   object
#  6   tenure.tenureType                 7467 non-null   object
#  7   tenure.yearsRemainingOnLease      494 non-null    float64
#  8   address.outcode                   8005 non-null   object
#  9   address.incode                    8005 non-null   object
#  10  location.latitude                 8005 non-null   object
#  11  location.longitude                8005 non-null   float64
#  12  analyticsProperty.added           10375 non-null  int64
#  13  analyticsProperty.auctionOnly     7990 non-null   object
#  14  analyticsProperty.minSizeFt       1255 non-null   float64
#  15  analyticsProperty.maxSizeFt       1255 non-null   float64
#  16  prices.pricePerSqFt               10375 non-null  int64
#  17  analyticsProperty.ownership       7989 non-null   object
#  18  analyticsProperty.preOwned        7990 non-null   object
#  19  analyticsProperty.priceQualifier  7990 non-null   object
#  20  analyticsProperty.soldSTC         7989 non-null   object
#  21  Price                             10375 non-null  object
# dtypes: float64(7), int64(2), object(13)
# memory usage: 1.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10375 entries, 123171899 to 97494416
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Station_Prox                      10375 non-null  float64
#  1   bedrooms_model                    7669 non-null   float64
#  2   bathrooms_model                   7455 non-null   float64
#  3   compass                           8005 non-null   object
#  4   borough_name                      9249 non-null   object
#  5   propertySubType                   8002 non-null   object
#  6   tenure.tenureType                 7467 non-null   object
#  7   tenure.yearsRemainingOnLease      494 non-null    float64
#  8   address.outcode                   8005 non-null   object
#  9   address.incode                    8005 non-null   object
#  10  location.latitude                 8005 non-null   object
#  11  location.longitude                8005 non-null   float64
#  12  analyticsProperty.added           10375 non-null  int64
#  13  analyticsProperty.auctionOnly     10375 non-null  bool
#  14  analyticsProperty.minSizeFt       1255 non-null   float64
#  15  analyticsProperty.maxSizeFt       1255 non-null   float64
#  16  prices.pricePerSqFt               10375 non-null  int64
#  17  analyticsProperty.ownership       7989 non-null   object
#  18  analyticsProperty.preOwned        7990 non-null   object
#  19  analyticsProperty.priceQualifier  7990 non-null   object
#  20  analyticsProperty.soldSTC         7989 non-null   object
#  21  Price                             10375 non-null  object
# dtypes: bool(1), float64(7), int64(2), object(12)
# memory usage: 1.8+ MB

# %%
df_original.head(5)
# Out:
#            Station_Prox  bedrooms_model  bathrooms_model compass borough_name  \
# ids
# 123171899           0.6             3.0              2.0       N      Enfield
# 85461000            0.6             3.0              1.0      EN      Enfield
# 85174740            0.4             2.0              1.0      EN      Enfield
# 124007903           0.2             2.0              1.0       N      Enfield
# 85614570            0.2             1.0              1.0       N      Enfield
#
#           propertySubType tenure.tenureType  tenure.yearsRemainingOnLease  \
# ids
# 123171899       Apartment         LEASEHOLD                           NaN
# 85461000         Terraced               NaN                           NaN
# 85174740    Semi-Detached          FREEHOLD                           NaN
# 124007903       Apartment         LEASEHOLD                           NaN
# 85614570             Flat         LEASEHOLD                           NaN
#
#           address.outcode address.incode  ... analyticsProperty.added  \
# ids                                       ...
# 123171899             N21            1JH  ...                20220509
# 85461000              EN8            8HW  ...                20220607
# 85174740              EN3            6LJ  ...                20220505
# 124007903             N14            6BZ  ...                20220617
# 85614570              N13            4RJ  ...                20220611
#
#            analyticsProperty.auctionOnly  analyticsProperty.minSizeFt  \
# ids
# 123171899                           True                          NaN
# 85461000                            True                          NaN
# 85174740                            True                          NaN
# 124007903                           True                          NaN
# 85614570                            True                          NaN
#
#            analyticsProperty.maxSizeFt  prices.pricePerSqFt  \
# ids
# 123171899                          NaN                   -1
# 85461000                           NaN                   -1
# 85174740                           NaN                   -1
# 124007903                          NaN                   -1
# 85614570                           NaN                   -1
#
#            analyticsProperty.ownership  analyticsProperty.preOwned  \
# ids
# 123171899         Non-shared ownership                      Resale
# 85461000          Non-shared ownership                      Resale
# 85174740          Non-shared ownership                      Resale
# 124007903         Non-shared ownership                      Resale
# 85614570          Non-shared ownership                      Resale
#
#           analyticsProperty.priceQualifier analyticsProperty.soldSTC     Price
# ids
# 123171899                      Offers Over                     False  475000.0
# 85461000                              None                     False  375000.0
# 85174740               Offers in Region of                      True  375000.0
# 124007903                             None                     False  375000.0
# 85614570               Offers in Excess of                     False  375000.0
#
# [5 rows x 22 columns]

# %%
df_original.describe()
# Out:
#        Station_Prox  bedrooms_model  bathrooms_model  \
# count  1.037500e+04     7669.000000      7455.000000
# mean   4.819320e+04        2.029991         1.261435
# std    2.194862e+06        0.951970         0.566892
# min    0.000000e+00        1.000000         1.000000
# 25%    2.000000e-01        1.000000         1.000000
# 50%    4.000000e-01        2.000000         1.000000
# 75%    5.000000e-01        3.000000         1.000000
# max    1.000000e+08        8.000000        16.000000
#
#        tenure.yearsRemainingOnLease  location.longitude  \
# count                    494.000000         8005.000000
# mean                     290.408907           -0.131528
# std                      346.662749            1.008393
# min                        0.000000           -0.407866
# 25%                      100.000000           -0.268666
# 50%                      121.000000           -0.155966
# 75%                      245.000000           -0.062132
# max                      999.000000           51.432040
#
#        analyticsProperty.added  analyticsProperty.minSizeFt  \
# count             1.037500e+04                  1255.000000
# mean              1.556836e+07                   835.368924
# std               8.508500e+06                  2147.997451
# min              -1.000000e+00                    29.000000
# 25%               2.021012e+07                   538.000000
# 50%               2.022022e+07                   702.000000
# 75%               2.022052e+07                   870.500000
# max               2.022063e+07                 74897.000000
#
#        analyticsProperty.maxSizeFt  prices.pricePerSqFt
# count                  1255.000000              10375.0
# mean                    837.371315                 -1.0
# std                    2148.069643                  0.0
# min                      29.000000                 -1.0
# 25%                     538.000000                 -1.0
# 50%                     704.000000                 -1.0
# 75%                     871.500000                 -1.0
# max                   74897.000000                 -1.0

# %%
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 5, 4
sns.set_style('whitegrid')

#sns.pairplot(df_original)

# %%
plottable_columns = [x for x in df_original.columns if x not in ['tenure.yearsRemainingOnLease', 'address.incode', 'address.outcode',
                                                                 'location.latitude', 'location.longitude', 'analyticsProperty.added',
       'analyticsProperty.auctionOnly', 'analyticsProperty.minSizeFt',
       'analyticsProperty.maxSizeFt', 'prices.pricePerSqFt',
       'analyticsProperty.ownership', 'analyticsProperty.preOwned',
       'analyticsProperty.priceQualifier', 'analyticsProperty.soldSTC',
                                                                 'Price']]

plottable_columns
# Out:
# ['Station_Prox',
#  'bedrooms_model',
#  'bathrooms_model',
#  'compass',
#  'borough_name',
#  'propertySubType',
#  'tenure.tenureType']

# %%
rcParams['figure.figsize'] = 10, 8
for each in plottable_columns:
    sns.countplot(y=each, data=df_original, palette='hls', orient='v')
    plt.show()
    #break

# %%
df_original.columns
# Out:
# Index(['Station_Prox', 'bedrooms_model', 'bathrooms_model', 'compass',
#        'borough_name', 'propertySubType', 'tenure.tenureType',
#        'tenure.yearsRemainingOnLease', 'address.outcode', 'address.incode',
#        'location.latitude', 'location.longitude', 'analyticsProperty.added',
#        'analyticsProperty.auctionOnly', 'analyticsProperty.minSizeFt',
#        'analyticsProperty.maxSizeFt', 'prices.pricePerSqFt',
#        'analyticsProperty.ownership', 'analyticsProperty.preOwned',
#        'analyticsProperty.priceQualifier', 'analyticsProperty.soldSTC',
#        'Price'],
#       dtype='object')

# %%
# Using pairplot we'll visualize the data for correlation

sns.pairplot(df_original, x_vars=['bedrooms_model', 'bathrooms_model','tenure.tenureType'], y_vars='Price', height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(df_original[(df_original['bedrooms_model'] == 2) & (df_original['propertySubType'] == 'Apartment')], x_vars='Price', y_vars=['borough_name','compass'], height=6, aspect=1, kind='scatter')
plt.show()

# %%
sns.pairplot(df_original[df_original['bedrooms_model'] == 2], x_vars=['Station_Prox'], y_vars='Price', size=7, aspect=1, kind='scatter')
plt.show()
# Out:
# /home/guava/Springboard/capstone_prework/venv/lib/python3.8/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df_original[df_original["type"] == "house"], x_vars=['bedrooms_model', 'compass'],
             y_vars='Price', height=5, aspect=1, kind='scatter')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 sns.pairplot(df_original[df_original["type"] == "house"], x_vars=['bedrooms_model', 'compass'],
#       2              y_vars='Price', height=5, aspect=1, kind='scatter')
#       3 plt.show()
#
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'type'

# %%
df_original.hist(figsize=(12,12))

# %%
df_original.hist(bins=50, figsize=(20,15))

# %%
df_original[(df_original['sq_ft'] != -1) & (df_original['Target'] != -1)].hist(bins=50, figsize=(20,15))

# %%
df_original["postcode"].value_counts()

# %%
df_original["type"].value_counts()

# %%
for each in df_original.columns:

    if each not in ['other_key_info','bullet_points','station_info','long_description']:
        print(each)
        print(df_original[each].value_counts())

# %%
df_original.iloc[:,:-1].shape,df_original.iloc[:,-1].shape,df_original["Target"].shape

# %%
df_original.head(20)

# %%
#df_original.drop("Links")
df = df_original.copy()
#df = df.drop(['Links','version_head','version_indiv','link'], axis=1)
df = df.drop(['Address','Description','Price','postcode'], axis=1)
df = df.drop(['borough','other_key_info','bullet_points','station_info'], axis=1)
df = df.drop(['short_description','long_description','hold_type','size'], axis=1)
df.head(20)

# %%
for column in ['type','compass','hold_type2']:
    df = pd.concat([df,pd.get_dummies(df[column], prefix=column)],axis=1)
    # now drop the original column (you don't need it anymore)
    df.drop([column],axis=1, inplace=True)
df.head(20)

# %%
if False:
    df.dropna(inplace=True)
    df

# %%
X = df.drop(["Target"],axis=1)
y = df["Target"]
X,y

# %% [markdown]
# # Exploratory Analysis

# %%
### does this work? it seems slow
#for each in df_original.columns[:2]:
#    x = df_original.plot(kind='scatter',x=each, y="Target")
#    plt.show()
#    #print (each)

# %%
### does this work? it doesn't seem to
#import numpy as np
#for each in df_original.columns:
#    print(each)
#
# x = df_original.plot(kind='scatter',x='bedrooms', y="Target")
# plt.yticks(np.arange(min(x), max(x)+1, 1000))
# plt.show()

# %%
# also not working
# df_original["Target"].describe()
# xx.describe()
# yy.dropna().describe()
# df_original["Target"]

# %%
#subset = df_original[df_original[['Target']].apply(lambda x: x[0].isdigit(), axis=1)]
pd.to_numeric(subset["Target"], 'coerce').dropna().astype(int)

#print(subset.head())
subset.describe()
df_original["Target"].value_counts()
df_original["Target"].dtypes
df_original.dtypes

#df_original["Target"] = df_original["Target"].astype("float")
#df_original.dtypes

pd.to_numeric(df_original["Target"], 'coerce').dropna().astype(int)

xx = subset['bedrooms']
yy = subset['Target']

xx,yy
subset['Target'] = pd.to_numeric(subset["Target"], 'coerce').dropna().astype(int)
subset['Target'].info()

# Creating a subplot with 2 row and 1 column
fig, (axes3) = plt.subplots(1, 1, figsize=(10,7))

# Plotting first axes object i.e. axes1 and labeling
# its x and y axes
axes3.scatter(xx, yy)
axes3.set_ylabel('y-axis')
axes3.set_xlabel('x-axis')

# Setting the interval of ticks of x-axis to 1 and of y-axis
# to 0.1 of first axes i.e. axes1.
axes3.xaxis.set_ticks(np.arange(0, 10, 1))
#axes3.yaxis.set_ticks(np.arange(0, 0.5, 0.1))
#axes3.yaxis.set_ticks([0,10])
axes3.yaxis.set_ticks(np.arange(0, 10000000,500000))

plt.show()

# %%
#subset = df_original[df_original[['Target']].apply(lambda x: x[0].isdigit(), axis=1)]
pd.to_numeric(subset["Target"], 'coerce').dropna().astype(int)

for x in subset.columns:

    if x not in ['other_key_info','bullet_points','station_info','long_description',
        'Address','Description',
        'borough'
                 ]:
        print(x)
        #x= 'bedrooms'
        y = 'Target'
        xx = subset[x]
        yy = subset[y]

        xx,yy

        # Creating a subplot with 2 row and 1 column
        fig, (axes3) = plt.subplots(1, 1, figsize=(10,7))

        # Plotting first axes object i.e. axes1 and labeling
        # its x and y axes
        axes3.scatter(xx, yy)
        axes3.set_ylabel(y)
        axes3.set_xlabel(x)

        # Setting the interval of ticks of x-axis to 1 and of y-axis
        # to 0.1 of first axes i.e. axes1.
        #axes3.yaxis.set_ticks(np.arange(0, 0.5, 0.1))
        #axes3.yaxis.set_ticks([0,10])
        axes3.yaxis.set_ticks(np.arange(0, 10000000,500000))

        #axes3.xaxis.set_ticks(np.arange(0, 10, 1))
        axes3.xaxis.set_ticks(np.arange(0, len(xx), len(xx)/10))

        plt.show()

# %%
sb.boxplot(x='Parch', y='Age', data=titanic_data, palette='hls')
