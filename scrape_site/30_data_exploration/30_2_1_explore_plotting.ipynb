# %%
import pandas as pd
# Import matplotlib and seaborn libraries to visualize the data

import matplotlib.pyplot as plt
import seaborn as sns

# Importing libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys

sys.path.append('../../globalfunction')  # setting path
import globalfunction.vv as vv  # importing
import globalfunction.pp as pp  # importing

import pandas as pd

df_original = vv.quick_data(publish=True,exceptional_nans=['size'])
df_original.head(50)
# Out:
# /media/sf_shared_files/Springboard_III/capstone_prep/globalfunction/vv.py:58: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_json1 = pd.read_csv(vv.LISTING_JSON_MODEL_FILE)  # EDIT 29-06-2022: There are bid listings and regular listings. I scrape them seporately and join them here.
# remove duplicates: 21347/30709/24762/24869 ==> 21347/21245/21035/21043
# dataframe length: 20976
# allowing Price to pass with 39 nulls/NANs
# allowing add_info to pass with 2442 nulls/NANs
# allowing type to pass with 79 nulls/NANs
# allowing bedrooms to pass with 908 nulls/NANs
# allowing bathrooms to pass with 1422 nulls/NANs
# dropping other_key_info because 20975 nulls/NANs is too many
# allowing bullet_points to pass with 2104 nulls/NANs
# allowing station_info to pass with 1 nulls/NANs
# dropping hold_type because 14986 nulls/NANs is too many
# allowing short_description to pass with 1 nulls/NANs
# allowing long_description to pass with 4 nulls/NANs
# allowing date_scraped_listing to pass with 1 nulls/NANs
# allowing virtualTours to pass with 11 nulls/NANs
# allowing rooms to pass with 11 nulls/NANs
# allowing nearestAirports to pass with 11 nulls/NANs
# allowing nearestStations to pass with 11 nulls/NANs
# allowing showSchoolInfo to pass with 11 nulls/NANs
# allowing channel to pass with 11 nulls/NANs
# allowing sizings to pass with 11 nulls/NANs
# allowing bedrooms_model to pass with 918 nulls/NANs
# allowing bathrooms_model to pass with 1432 nulls/NANs
# allowing transactionType to pass with 11 nulls/NANs
# allowing tags to pass with 11 nulls/NANs
# allowing infoReelItems to pass with 11 nulls/NANs
# allowing soldPropertyType to pass with 11 nulls/NANs
# dropping auctionProvider because 20976 nulls/NANs is too many
# allowing propertySubType to pass with 11 nulls/NANs
# allowing businessForSale to pass with 11 nulls/NANs
# allowing commercial to pass with 11 nulls/NANs
# allowing commercialUseClasses to pass with 11 nulls/NANs
# dropping affordableBuyingScheme because 20976 nulls/NANs is too many
# allowing status.published to pass with 11 nulls/NANs
# allowing status.archived to pass with 11 nulls/NANs
# allowing text.description to pass with 11 nulls/NANs
# allowing text.propertyPhrase to pass with 11 nulls/NANs
# allowing text.shareText to pass with 11 nulls/NANs
# allowing text.shareDescription to pass with 11 nulls/NANs
# allowing text.pageTitle to pass with 11 nulls/NANs
# allowing text.shortDescription to pass with 11 nulls/NANs
# allowing prices.primaryPrice to pass with 11 nulls/NANs
# dropping prices.secondaryPrice because 20976 nulls/NANs is too many
# dropping prices.displayPriceQualifier because 11975 nulls/NANs is too many
# dropping prices.pricePerSqFt because 17694 nulls/NANs is too many
# dropping prices.exchangeRate because 20976 nulls/NANs is too many
# allowing address.displayAddress to pass with 11 nulls/NANs
# allowing address.countryCode to pass with 11 nulls/NANs
# dropping address.deliveryPointId because 7217 nulls/NANs is too many
# allowing address.ukCountry to pass with 11 nulls/NANs
# allowing address.outcode to pass with 11 nulls/NANs
# allowing address.incode to pass with 11 nulls/NANs
# allowing location.latitude to pass with 11 nulls/NANs
# allowing location.longitude to pass with 11 nulls/NANs
# allowing location.circleRadiusOnMap to pass with 11 nulls/NANs
# allowing location.zoomLevel to pass with 11 nulls/NANs
# allowing location.pinType to pass with 11 nulls/NANs
# allowing location.showMap to pass with 11 nulls/NANs
# allowing misInfo.branchId to pass with 11 nulls/NANs
# dropping misInfo.offerAdvertStampTypeId because 20845 nulls/NANs is too many
# allowing misInfo.premiumDisplay to pass with 11 nulls/NANs
# dropping misInfo.premiumDisplayStampId because 15716 nulls/NANs is too many
# allowing misInfo.brandPlus to pass with 11 nulls/NANs
# allowing misInfo.featuredProperty to pass with 11 nulls/NANs
# allowing listingHistory.listingUpdateReason to pass with 12 nulls/NANs
# allowing contactInfo.contactMethod to pass with 11 nulls/NANs
# allowing contactInfo.telephoneNumbers.localNumber to pass with 15 nulls/NANs
# dropping contactInfo.telephoneNumbers.internationalNumber because 20976 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerText because 20976 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerTitle because 20976 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerDescription because 20976 nulls/NANs is too many
# allowing tenure.tenureType to pass with 1468 nulls/NANs
# dropping tenure.yearsRemainingOnLease because 19650 nulls/NANs is too many
# dropping tenure.message because 19538 nulls/NANs is too many
# allowing sharedOwnership.sharedOwnership to pass with 11 nulls/NANs
# dropping sharedOwnership.ownershipPercentage because 20959 nulls/NANs is too many
# dropping sharedOwnership.rentPrice because 20964 nulls/NANs is too many
# allowing sharedOwnership.rentFrequency to pass with 3475 nulls/NANs
# allowing livingCosts.councilTaxExempt to pass with 11 nulls/NANs
# allowing livingCosts.councilTaxIncluded to pass with 11 nulls/NANs
# dropping livingCosts.annualGroundRent because 20925 nulls/NANs is too many
# dropping livingCosts.groundRentReviewPeriodInYears because 20962 nulls/NANs is too many
# dropping livingCosts.groundRentPercentageIncrease because 20970 nulls/NANs is too many
# dropping livingCosts.annualServiceCharge because 20911 nulls/NANs is too many
# dropping livingCosts.councilTaxBand because 20752 nulls/NANs is too many
# dropping dfpAdInfo.channel because 20969 nulls/NANs is too many
# dropping dfpAdInfo.targeting because 20969 nulls/NANs is too many
# dropping auctionProvider.endDate because 20969 nulls/NANs is too many
# dropping auctionProvider.auctionTimeRemaining because 20969 nulls/NANs is too many
# dropping auctionProvider.bid because 20976 nulls/NANs is too many
# allowing date_scraped_meta to pass with 6 nulls/NANs
# allowing analyticsBranch.agentType to pass with 6 nulls/NANs
# allowing analyticsBranch.branchId to pass with 6 nulls/NANs
# allowing analyticsBranch.branchName to pass with 6 nulls/NANs
# allowing analyticsBranch.brandName to pass with 6 nulls/NANs
# allowing analyticsBranch.companyName to pass with 6 nulls/NANs
# allowing analyticsBranch.companyTradingName to pass with 4768 nulls/NANs
# allowing analyticsBranch.companyType to pass with 6 nulls/NANs
# allowing analyticsBranch.pageType to pass with 6 nulls/NANs
# allowing analyticsProperty.added to pass with 6 nulls/NANs
# allowing analyticsProperty.auctionOnly to pass with 6 nulls/NANs
# allowing analyticsProperty.beds to pass with 6 nulls/NANs
# allowing analyticsProperty.businessForSale to pass with 6 nulls/NANs
# allowing analyticsProperty.country to pass with 6 nulls/NANs
# allowing analyticsProperty.currency to pass with 6 nulls/NANs
# allowing analyticsProperty.floorplanCount to pass with 6 nulls/NANs
# allowing analyticsProperty.furnishedType to pass with 6 nulls/NANs
# allowing analyticsProperty.hasOnlineViewing to pass with 6 nulls/NANs
# allowing analyticsProperty.imageCount to pass with 6 nulls/NANs
# allowing analyticsProperty.latitude to pass with 6 nulls/NANs
# allowing analyticsProperty.longitude to pass with 6 nulls/NANs
# allowing analyticsProperty.letAgreed to pass with 6 nulls/NANs
# allowing analyticsProperty.lettingType to pass with 6 nulls/NANs
# dropping analyticsProperty.maxSizeAc because 17694 nulls/NANs is too many
# dropping analyticsProperty.maxSizeFt because 17694 nulls/NANs is too many
# dropping analyticsProperty.minSizeAc because 17694 nulls/NANs is too many
# dropping analyticsProperty.minSizeFt because 17694 nulls/NANs is too many
# allowing analyticsProperty.ownership to pass with 6 nulls/NANs
# allowing analyticsProperty.preOwned to pass with 6 nulls/NANs
# allowing analyticsProperty.priceQualifier to pass with 6 nulls/NANs
# allowing analyticsProperty.propertyId to pass with 6 nulls/NANs
# allowing analyticsProperty.propertySubType to pass with 6 nulls/NANs
# allowing analyticsProperty.propertyType to pass with 6 nulls/NANs
# allowing analyticsProperty.retirement to pass with 6 nulls/NANs
# dropping analyticsProperty.selectedCurrency because 20976 nulls/NANs is too many
# allowing analyticsProperty.soldSTC to pass with 6 nulls/NANs
# allowing analyticsProperty.videoProvider to pass with 6 nulls/NANs
# allowing analyticsProperty.viewType to pass with 6 nulls/NANs
# dropping Unnamed: 46 because 20976 nulls/NANs is too many
# allowing borough_name to pass with 22 nulls/NANs
# allowing floorplan_count to pass with 11 nulls/NANs
#                                     Description     Price  \
# ids
# 124059707               3 bedroom flat for sale  325000.0
# 124056446               1 bedroom flat for sale  225000.0
# 124059386               1 bedroom flat for sale  225000.0
# 85324458           1 bedroom apartment for sale  225000.0
# 113260523               1 bedroom flat for sale  225000.0
# 116165987          1 bedroom apartment for sale  225000.0
# 120508688               1 bedroom flat for sale  225000.0
# 122634287          1 bedroom apartment for sale  225000.0
# 123610880               1 bedroom flat for sale  225000.0
# 120845903          1 bedroom apartment for sale  230000.0
# 124597466               1 bedroom flat for sale  230000.0
# 121509167               1 bedroom flat for sale  230000.0
# 124116800               1 bedroom flat for sale  230000.0
# 85134405           2 bedroom apartment for sale  425000.0
# 106840967          2 bedroom apartment for sale  210000.0
# 120673064          1 bedroom apartment for sale  210000.0
# 124365830               1 bedroom flat for sale  215000.0
# 85412691                1 bedroom flat for sale  215000.0
# 124341599               1 bedroom flat for sale  220000.0
# 123555122               1 bedroom flat for sale  220000.0
# 96635869                1 bedroom flat for sale  220000.0
# 120563651          1 bedroom apartment for sale  220000.0
# 114282032               1 bedroom flat for sale  220000.0
# 120859304         1 bedroom maisonette for sale  220000.0
# 123710081  1 bedroom ground floor flat for sale  220000.0
# 122724968               1 bedroom flat for sale  220000.0
# 124034645               1 bedroom flat for sale  375000.0
# 123409187               2 bedroom flat for sale  375000.0
# 123418823               2 bedroom flat for sale  375000.0
# 114255761         2 bedroom maisonette for sale  375000.0
# 121172195               2 bedroom flat for sale  375000.0
# 122084081          2 bedroom apartment for sale  375000.0
# 73509738           1 bedroom apartment for sale  375000.0
# 123609983               2 bedroom flat for sale  375000.0
# 120818840          2 bedroom apartment for sale  375000.0
# 123966596               2 bedroom flat for sale  375000.0
# 120788990          2 bedroom apartment for sale  375000.0
# 120685424               2 bedroom flat for sale  375000.0
# 122440208         1 bedroom maisonette for sale  375000.0
# 121942022         2 bedroom maisonette for sale  375000.0
# 122423642          2 bedroom apartment for sale  375000.0
# 85715532                2 bedroom flat for sale  375000.0
# 101942609          2 bedroom apartment for sale  375000.0
# 84845169           1 bedroom apartment for sale  375000.0
# 120335105              2 bedroom house for sale  375000.0
# 85320837   1 bedroom ground floor flat for sale  375000.0
# 123420218               2 bedroom flat for sale  375000.0
# 118579607               2 bedroom flat for sale  375000.0
# 84861576          2 bedroom maisonette for sale  375000.0
# 120873797          2 bedroom apartment for sale  375000.0
#
#                                                     add_info  \
# ids
# 124059707          Added on 18/06/2022 by haart, Barkingside
# 124056446     Added on 18/06/2022 by Ideal Locations, Ilford
# 124059386     Added on 18/06/2022 by Ideal Locations, Ilford
# 85324458                Added on 17/05/2022 by haart, Ilford
# 113260523  Reduced on 11/11/2021 by Sandra Davidson Estat...
# 116165987          Added on 18/06/2022 by Outlook, Stratford
# 120508688               Added on 01/03/2022 by haart, Ilford
# 122634287  Reduced on 29/04/2022 by Highcastle Estates, L...
# 123610880              Added on 23/05/2022 by Strike, London
# 120845903               Added on 09/03/2022 by haart, Ilford
# 124597466     Added on 02/07/2022 by Kurtis Property, Ilford
# 121509167        Reduced on 25/04/2022 by haart, Barkingside
# 124116800              Added on 20/06/2022 by Strike, London
# 85134405   Added on 05/05/2022 by Farr O'Neil, Buckhurst ...
# 106840967             Reduced on 07/06/2022 by haart, Ilford
# 120673064               Added on 04/03/2022 by haart, Ilford
# 124365830  Reduced on 05/05/2022 by Stonebridge Estates, ...
# 85412691      Added on 01/06/2022 by Ideal Locations, Ilford
# 124341599               Added on 26/06/2022 by haart, Ilford
# 123555122  Added on 21/05/2022 by Sandra Davidson Estate ...
# 96635869   Reduced on 09/06/2022 by Alex Crown Lettings &...
# 120563651  Reduced on 22/04/2022 by William H. Brown Inco...
# 114282032  Added on 14/03/2022 by Sandra Davidson Estate ...
# 120859304  Reduced on 01/10/2020 by YOUR MOVE Glenwood, C...
# 123710081  Added on 26/05/2022 by Purplebricks, covering ...
# 122724968               Added on 22/04/2022 by haart, Ilford
# 124034645           Added on 17/06/2022 by Foxtons, Kingston
# 123409187  Added on 16/05/2022 by Seymours Estate Agents,...
# 123418823  Added on 16/05/2022 by Seymours Estate Agents,...
# 114255761  Reduced on 16/11/2021 by Greenfield Estate Age...
# 121172195  Reduced on 08/04/2022 by Dexters, Kingston Upo...
# 122084081  Reduced on 05/04/2022 by Curchods Estate Agent...
# 73509738   Added on 22/02/2022 by Stack & Bonner, Kingsto...
# 123609983           Added on 23/05/2022 by Foxtons, Kingston
# 120818840       Reduced on 06/04/2022 by Winkworth, Surbiton
# 123966596           Added on 16/06/2022 by Dexters, Surbiton
# 120788990        Added on 08/03/2022 by Hawes & Co, Surbiton
# 120685424  Added on 13/04/2022 by Seymours Estate Agents,...
# 122440208  Added on 14/04/2022 by Dexters, Kingston Upon ...
# 121942022  Reduced on 05/05/2022 by Cavender Estate Agent...
# 122423642  Added on 14/04/2022 by Humphrey and Brand Resi...
# 85715532   Added on 14/06/2022 by Cavender Estate Agent, ...
# 101942609  Added on 13/01/2021 by Leaders Sales, Kingston...
# 84845169   Added on 27/04/2022 by Curchods Estate Agents,...
# 120335105  Added on 24/02/2022 by Harmes Turner Brown, Ea...
# 85320837   Added on 31/05/2022 by Humphrey and Brand Resi...
# 123420218  Added on 16/05/2022 by Carringtons, Kingston Hill
# 118579607  Added on 11/01/2022 by Kinleigh Folkard & Hayw...
# 84861576   Added on 27/04/2022 by Seymours Estate Agents,...
# 120873797  Added on 09/03/2022 by Leaders Sales, Kingston...
#
#            distance_to_any_train         type  bedrooms  bathrooms  \
# ids
# 124059707                    0.5         Flat       3.0        1.0
# 124056446                    0.1         Flat       1.0        1.0
# 124059386                    0.3         Flat       1.0        1.0
# 85324458                     0.9    Apartment       1.0        1.0
# 113260523                    0.4         Flat       1.0        1.0
# 116165987                    0.3    Apartment       1.0        1.0
# 120508688                    0.3         Flat       1.0        1.0
# 122634287                    0.5    Apartment       1.0        1.0
# 123610880                    0.3         Flat       1.0        1.0
# 120845903                    0.3    Apartment       1.0        1.0
# 124597466                    0.6         Flat       1.0        1.0
# 121509167                    0.7         Flat       1.0        1.0
# 124116800                    0.6         Flat       1.0        1.0
# 85134405                     0.7    Apartment       2.0        2.0
# 106840967                    0.6    Apartment       2.0        1.0
# 120673064                    0.3    Apartment       1.0        1.0
# 124365830                    0.2         Flat       1.0        1.0
# 85412691                     0.0         Flat       1.0        1.0
# 124341599                    0.3         Flat       1.0        1.0
# 123555122                    0.9         Flat       1.0        1.0
# 96635869                     0.4         Flat       1.0        1.0
# 120563651                    0.7    Apartment       1.0        1.0
# 114282032                    0.3         Flat       1.0        1.0
# 120859304                    0.0   Maisonette       1.0        1.0
# 123710081                    0.3  Ground Flat       1.0        1.0
# 122724968                    0.5         Flat       1.0        1.0
# 124034645                    0.4         Flat       1.0        1.0
# 123409187                    0.5         Flat       2.0        1.0
# 123418823                    0.3         Flat       2.0        1.0
# 114255761                    0.6   Maisonette       2.0        1.0
# 121172195                    0.2         Flat       2.0        1.0
# 122084081                    0.4    Apartment       2.0        1.0
# 73509738                     0.3    Apartment       1.0        1.0
# 123609983                    0.6         Flat       2.0        1.0
# 120818840                    0.3    Apartment       2.0        1.0
# 123966596                    0.8         Flat       2.0        1.0
# 120788990                    0.5    Apartment       2.0        1.0
# 120685424                    0.4         Flat       2.0        1.0
# 122440208                    0.4   Maisonette       1.0        1.0
# 121942022                    0.1   Maisonette       2.0        1.0
# 122423642                    0.1    Apartment       2.0        1.0
# 85715532                     0.4         Flat       2.0        1.0
# 101942609                    0.0    Apartment       2.0        1.0
# 84845169                     0.7    Apartment       1.0        1.0
# 120335105                    0.5        House       2.0        1.0
# 85320837                     0.3  Ground Flat       1.0        1.0
# 123420218                    0.2         Flat       2.0        1.0
# 118579607                    0.3         Flat       2.0        1.0
# 84861576                     0.9   Maisonette       2.0        1.0
# 120873797                    0.0    Apartment       2.0        1.0
#
#                               size  \
# ids
# 124059707                      NaN
# 124056446                      NaN
# 124059386                      NaN
# 85324458                       NaN
# 113260523                      NaN
# 116165987                      NaN
# 120508688                      NaN
# 122634287                      NaN
# 123610880                      NaN
# 120845903                      NaN
# 124597466                      NaN
# 121509167                      NaN
# 124116800                      NaN
# 85134405                       NaN
# 106840967                      NaN
# 120673064                      NaN
# 124365830  474 sq. ft.;(44 sq. m.)
# 85412691                       NaN
# 124341599                      NaN
# 123555122                      NaN
# 96635869                       NaN
# 120563651                      NaN
# 114282032                      NaN
# 120859304                      NaN
# 123710081                      NaN
# 122724968                      NaN
# 124034645  534 sq. ft.;(50 sq. m.)
# 123409187                      NaN
# 123418823                      NaN
# 114255761                      NaN
# 121172195                      NaN
# 122084081                      NaN
# 73509738   665 sq. ft.;(62 sq. m.)
# 123609983  641 sq. ft.;(60 sq. m.)
# 120818840                      NaN
# 123966596                      NaN
# 120788990                      NaN
# 120685424                      NaN
# 122440208                      NaN
# 121942022                      NaN
# 122423642                      NaN
# 85715532                       NaN
# 101942609                      NaN
# 84845169                       NaN
# 120335105                      NaN
# 85320837                       NaN
# 123420218  759 sq. ft.;(70 sq. m.)
# 118579607                      NaN
# 84861576                       NaN
# 120873797                      NaN
#
#                                                bullet_points  \
# ids
# 124059707  2-3 Bedrooms;First Floor Flat;Well Presented T...
# 124056446  Great Condition;Perfect for a FTB;Close to Exc...
# 124059386  1 Bedroom Flat;Excellent condition;Close to Lo...
# 85324458   Purpose Built Second Floor Flat;Double Bedroom...
# 113260523  EPC RATING C;Duplex Flat;One bedroom;Lounge;Ki...
# 116165987  Long Lease;Chain Free;Top Floor Flat;0.3 Miles...
# 120508688  One Bedroom Conversion Flat;Ground Floor;Spaci...
# 122634287  Cloakroom;Double Glazing;Fitted Bathroom;Fitte...
# 123610880  garden;close-to-local-amenities;sought-after-l...
# 120845903  Purpose Built;First Floor;Large Double Bedroom...
# 124597466  One Bedroom Flat;Share Of Freehold;Modern Bloc...
# 121509167  First Floor Flat;One Double Bedroom;Spacious L...
# 124116800          Location;Amenities;Transport;Project flat
# 85134405   Stylish top floor apartment;Two double bedroom...
# 106840967  Two Double Bedrooms;Top Floor (3rd floor);Loun...
# 120673064  Ground Floor Purpose Built Flat;Double Bedroom...
# 124365830  ONE BEDROOM FIRST FLOOR FLAT VICTORIAN CONVERS...
# 85412691   One Bedroom FLAT;Excellent Location;Minute wal...
# 124341599  First Foor Maisonette;Large Lounge & Separate ...
# 123555122  EPC RATING TBC;One bedrooms;Lounge;Kitchen;Lea...
# 96635869   GUIDE PRICE £220K - £235K;CHAIN FREE;Lovely on...
# 120563651  One Bedroom;First Floor;Balcony;Chain Free;Eas...
# 114282032  EPC - C;DOUBLE GLAZED WINDOW;ALLOCATED PARKING...
# 120859304  First Floor Maisonette;One Bedroom;Allocated P...
# 123710081  Chain Free ;Bright And Spacious Throughout ;Cl...
# 122724968  Ground Floor Conversion Flat;One Bedroom;Loung...
# 124034645  Fantastic 1 bedroom Ground floor flat;Spacious...
# 123409187  Convenient Location;Ground Floor Apartment;Vic...
# 123418823  Modern Purpose Built Development;Third Floor;S...
# 114255761  Private Garden;Private Entrance;Close Proximit...
# 121172195  Purpose Built Apartment;Two Double Bedrooms;Sp...
# 122084081  Luxury bathroom;Lease 116 years remaining; Gro...
# 73509738   Spacious 1 bedroom apartment;Riverside Develop...
# 123609983  Superb 2 bedroom ground floor flat;Bright and ...
# 120818840  Close to Surbiton Station;Ideal Investment or ...
# 123966596  Ground Floor;Ample Storage;Two Double Bedrooms...
# 120788990  No Onward Chain;Two Double bedroom;Open-Plan K...
# 120685424  Quiet, Central Location;Close to Mainline Stat...
# 122440208  One Double Bedroom;Bay Fronted Reception Room;...
# 121942022  Two double bedrooms;Recently refurbished;New k...
# 122423642  Two Double Bedroom Apartment;Modern fitted kit...
# 85715532   Central location;Ground floor flat with lots o...
# 101942609  Two Double Bedroom Apartment;Bright And Spacio...
# 84845169   First floor one double bedroom maisonette;Priv...
# 120335105  MID TERRACE PERIOD PROPERTY;TWO BEDROOMS;PRIVA...
# 85320837   No onward chain;Prime location in the heart of...
# 123420218  Ideal for investor or buyer who wishes to reno...
# 118579607  Two Double Bedrooms;Private Entrance;Detached ...
# 84861576   Quiet Cul-De-Sac Location;Easy Access to Surbi...
# 120873797  Two Double Bedroom Apartment;Gated Development...
#
#                                                 station_info  ...  \
# ids                                                           ...
# 124059707  [(0.5, 'Gants Hill Station', 'svg-underground'...  ...
# 124056446  [(0.1, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 124059386  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 85324458   [(0.9, 'Barking Station', 'svg-nationalrail;sv...  ...
# 113260523  [(0.4, 'Seven Kings Station', 'svg-nationalrai...  ...
# 116165987  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 120508688  [(0.3, 'Ilford Station', 'svg-nationalrail'), ...  ...
# 122634287  [(0.5, 'Gants Hill Station', 'svg-underground'...  ...
# 123610880  [(0.3, 'Newbury Park Station', 'svg-undergroun...  ...
# 120845903  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 124597466  [(0.6, 'Upney Station', 'svg-underground'), (0...  ...
# 121509167  [(0.7, 'Redbridge Station', 'svg-underground')...  ...
# 124116800  [(0.6, 'Ilford Station', 'svg-nationalrail'), ...  ...
# 85134405   [(0.7, 'Roding Valley Station', 'svg-undergrou...  ...
# 106840967  [(0.6, 'Barking Station', 'svg-nationalrail;sv...  ...
# 120673064  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 124365830  [(0.2, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 85412691   [(0.0, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 124341599  [(0.3, 'Ilford Station', 'svg-nationalrail'), ...  ...
# 123555122  [(0.9, 'Barking Station', 'svg-nationalrail;sv...  ...
# 96635869   [(0.4, 'Ilford Station', 'svg-nationalrail'), ...  ...
# 120563651  [(0.7, 'Upney Station', 'svg-underground'), (1...  ...
# 114282032  [(0.3, 'Chadwell Heath Station', 'svg-national...  ...
# 120859304  [(0.0, 'Chadwell Heath Station', 'svg-national...  ...
# 123710081  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 122724968  [(0.5, 'Ilford Station', 'svg-nationalrail'), ...  ...
# 124034645  [(0.4, 'Surbiton Station', 'svg-nationalrail')...  ...
# 123409187  [(0.5, 'Surbiton Station', 'svg-nationalrail')...  ...
# 123418823  [(0.3, 'Surbiton Station', 'svg-nationalrail')...  ...
# 114255761  [(0.6, 'Tolworth Station', 'svg-nationalrail')...  ...
# 121172195  [(0.2, 'Kingston Station', 'svg-nationalrail')...  ...
# 122084081  [(0.4, 'New Malden Station', 'svg-nationalrail...  ...
# 73509738   [(0.3, 'Hampton Wick Station', 'svg-nationalra...  ...
# 123609983  [(0.6, 'Kingston Station', 'svg-nationalrail')...  ...
# 120818840  [(0.3, 'Surbiton Station', 'svg-nationalrail')...  ...
# 123966596  [(0.8, 'Chessington North Station', 'svg-natio...  ...
# 120788990  [(0.5, 'Surbiton Station', 'svg-nationalrail')...  ...
# 120685424  [(0.4, 'Surbiton Station', 'svg-nationalrail')...  ...
# 122440208  [(0.4, 'Berrylands Station', 'svg-nationalrail...  ...
# 121942022  [(0.1, 'Berrylands Station', 'svg-nationalrail...  ...
# 122423642  [(0.1, 'Surbiton Station', 'svg-nationalrail')...  ...
# 85715532   [(0.4, 'Kingston Station', 'svg-nationalrail')...  ...
# 101942609  [(0.0, 'Kingston Station', 'svg-nationalrail')...  ...
# 84845169   [(0.7, 'Berrylands Station', 'svg-nationalrail...  ...
# 120335105  [(0.5, 'Tolworth Station', 'svg-nationalrail')...  ...
# 85320837   [(0.3, 'Surbiton Station', 'svg-nationalrail')...  ...
# 123420218  [(0.2, 'Norbiton Station', 'svg-nationalrail')...  ...
# 118579607  [(0.3, 'Kingston Station', 'svg-nationalrail')...  ...
# 84861576   [(0.9, 'Chessington North Station', 'svg-natio...  ...
# 120873797  [(0.0, 'Kingston Station', 'svg-nationalrail')...  ...
#
#           analyticsProperty.priceQualifier analyticsProperty.propertyId  \
# ids
# 124059707                      Guide Price                  124059707.0
# 124056446                             None                  124056446.0
# 124059386                             None                  124059386.0
# 85324458                       Guide Price                   85324458.0
# 113260523              Offers in Excess of                  113260523.0
# 116165987              Offers in Excess of                  116165987.0
# 120508688                      Guide Price                  120508688.0
# 122634287                             None                  122634287.0
# 123610880                             None                  123610880.0
# 120845903                             None                  120845903.0
# 124597466                             None                  124597466.0
# 121509167                      Guide Price                  121509167.0
# 124116800                      Guide Price                  124116800.0
# 85134405                       Guide Price                   85134405.0
# 106840967                      Offers Over                  106840967.0
# 120673064                      Guide Price                  120673064.0
# 124365830                             None                  124365830.0
# 85412691                       Guide Price                   85412691.0
# 124341599                      Guide Price                  124341599.0
# 123555122              Offers in Excess of                  123555122.0
# 96635869                       Guide Price                   96635869.0
# 120563651                      Fixed Price                  120563651.0
# 114282032                      Guide Price                  114282032.0
# 120859304                             None                  120859304.0
# 123710081                             None                  123710081.0
# 122724968                             None                  122724968.0
# 124034645                             None                  124034645.0
# 123409187                             None                  123409187.0
# 123418823                             None                  123418823.0
# 114255761                             None                  114255761.0
# 121172195                             None                  121172195.0
# 122084081                             None                  122084081.0
# 73509738                              None                   73509738.0
# 123609983                             None                  123609983.0
# 120818840                             None                  120818840.0
# 123966596                             None                  123966596.0
# 120788990                             None                  120788990.0
# 120685424                      Guide Price                  120685424.0
# 122440208                             None                  122440208.0
# 121942022                      Guide Price                  121942022.0
# 122423642                             None                  122423642.0
# 85715532                              None                   85715532.0
# 101942609                             None                  101942609.0
# 84845169                              None                   84845169.0
# 120335105              Offers in Region of                  120335105.0
# 85320837                              None                   85320837.0
# 123420218                             None                  123420218.0
# 118579607                             None                  118579607.0
# 84861576                              None                   84861576.0
# 120873797                             None                  120873797.0
#
#           analyticsProperty.propertySubType analyticsProperty.propertyType  \
# ids
# 124059707                              Flat             Flats / Apartments
# 124056446                              Flat             Flats / Apartments
# 124059386                              Flat             Flats / Apartments
# 85324458                          Apartment             Flats / Apartments
# 113260523                              Flat             Flats / Apartments
# 116165987                         Apartment             Flats / Apartments
# 120508688                              Flat             Flats / Apartments
# 122634287                         Apartment             Flats / Apartments
# 123610880                              Flat             Flats / Apartments
# 120845903                         Apartment             Flats / Apartments
# 124597466                              Flat             Flats / Apartments
# 121509167                              Flat             Flats / Apartments
# 124116800                              Flat             Flats / Apartments
# 85134405                          Apartment             Flats / Apartments
# 106840967                         Apartment             Flats / Apartments
# 120673064                         Apartment             Flats / Apartments
# 124365830                              Flat             Flats / Apartments
# 85412691                               Flat             Flats / Apartments
# 124341599                              Flat             Flats / Apartments
# 123555122                              Flat             Flats / Apartments
# 96635869                               Flat             Flats / Apartments
# 120563651                         Apartment             Flats / Apartments
# 114282032                              Flat             Flats / Apartments
# 120859304                        Maisonette             Flats / Apartments
# 123710081                       Ground Flat             Flats / Apartments
# 122724968                              Flat             Flats / Apartments
# 124034645                              Flat             Flats / Apartments
# 123409187                              Flat             Flats / Apartments
# 123418823                              Flat             Flats / Apartments
# 114255761                        Maisonette             Flats / Apartments
# 121172195                              Flat             Flats / Apartments
# 122084081                         Apartment             Flats / Apartments
# 73509738                          Apartment             Flats / Apartments
# 123609983                              Flat             Flats / Apartments
# 120818840                         Apartment             Flats / Apartments
# 123966596                              Flat             Flats / Apartments
# 120788990                         Apartment             Flats / Apartments
# 120685424                              Flat             Flats / Apartments
# 122440208                        Maisonette             Flats / Apartments
# 121942022                        Maisonette             Flats / Apartments
# 122423642                         Apartment             Flats / Apartments
# 85715532                               Flat             Flats / Apartments
# 101942609                         Apartment             Flats / Apartments
# 84845169                          Apartment             Flats / Apartments
# 120335105                             House                         Houses
# 85320837                        Ground Flat             Flats / Apartments
# 123420218                              Flat             Flats / Apartments
# 118579607                              Flat             Flats / Apartments
# 84861576                         Maisonette             Flats / Apartments
# 120873797                         Apartment             Flats / Apartments
#
#           analyticsProperty.retirement analyticsProperty.soldSTC  \
# ids
# 124059707                        False                     False
# 124056446                        False                      True
# 124059386                        False                      True
# 85324458                         False                      True
# 113260523                        False                      True
# 116165987                        False                     False
# 120508688                        False                     False
# 122634287                        False                      True
# 123610880                        False                      True
# 120845903                        False                      True
# 124597466                        False                     False
# 121509167                        False                      True
# 124116800                        False                     False
# 85134405                         False                     False
# 106840967                        False                      True
# 120673064                        False                      True
# 124365830                        False                      True
# 85412691                         False                     False
# 124341599                        False                     False
# 123555122                        False                      True
# 96635869                         False                     False
# 120563651                        False                     False
# 114282032                        False                      True
# 120859304                        False                      True
# 123710081                        False                     False
# 122724968                        False                      True
# 124034645                        False                     False
# 123409187                        False                     False
# 123418823                        False                     False
# 114255761                        False                      True
# 121172195                        False                     False
# 122084081                        False                      True
# 73509738                         False                      True
# 123609983                        False                     False
# 120818840                        False                     False
# 123966596                        False                     False
# 120788990                        False                      True
# 120685424                        False                      True
# 122440208                        False                     False
# 121942022                        False                      True
# 122423642                        False                      True
# 85715532                         False                     False
# 101942609                        False                      True
# 84845169                         False                      True
# 120335105                        False                      True
# 85320837                         False                     False
# 123420218                        False                      True
# 118579607                        False                     False
# 84861576                         False                     False
# 120873797                        False                      True
#
#           analyticsProperty.videoProvider analyticsProperty.viewType  \
# ids
# 124059707                        No Video                    Current
# 124056446                        No Video                    Current
# 124059386                        No Video                    Current
# 85324458                         No Video                    Current
# 113260523                        No Video                    Current
# 116165987                        No Video                    Current
# 120508688                        No Video                    Current
# 122634287                        No Video                    Current
# 123610880                        No Video                    Current
# 120845903                        Embedded                    Current
# 124597466                        No Video                    Current
# 121509167                        Embedded                    Current
# 124116800                        No Video                    Current
# 85134405                         No Video                    Current
# 106840967                        No Video                    Current
# 120673064                        Embedded                    Current
# 124365830                        No Video                    Current
# 85412691                         No Video                    Current
# 124341599                        No Video                    Current
# 123555122                        No Video                    Current
# 96635869                         No Video                    Current
# 120563651                        No Video                    Current
# 114282032                        No Video                    Current
# 120859304                        No Video                    Current
# 123710081                   External Link                    Current
# 122724968                        No Video                    Current
# 124034645                        No Video                    Current
# 123409187                        No Video                    Current
# 123418823                        No Video                    Current
# 114255761                        Embedded                    Current
# 121172195                        No Video                    Current
# 122084081                        No Video                    Current
# 73509738                         No Video                    Current
# 123609983                        No Video                    Current
# 120818840                        No Video                    Current
# 123966596                        No Video                    Current
# 120788990                   External Link                    Current
# 120685424                        No Video                    Current
# 122440208                        No Video                    Current
# 121942022                        No Video                    Current
# 122423642                        No Video                    Current
# 85715532                         No Video                    Current
# 101942609                        No Video                    Current
# 84845169                         No Video                    Current
# 120335105                        No Video                    Current
# 85320837                         Embedded                    Current
# 123420218                        No Video                    Current
# 118579607                        No Video                    Current
# 84861576                         No Video                    Current
# 120873797                        No Video                    Current
#
#                    borough_name  floorplan_count
# ids
# 124059707             Redbridge              4.0
# 124056446             Redbridge              1.0
# 124059386             Redbridge              1.0
# 85324458              Redbridge              4.0
# 113260523             Redbridge              4.0
# 116165987             Redbridge              1.0
# 120508688             Redbridge              4.0
# 122634287             Redbridge              4.0
# 123610880             Redbridge              1.0
# 120845903             Redbridge              4.0
# 124597466             Redbridge              4.0
# 121509167             Redbridge              4.0
# 124116800             Redbridge              4.0
# 85134405              Redbridge              8.0
# 106840967             Redbridge              4.0
# 120673064             Redbridge              4.0
# 124365830             Redbridge              4.0
# 85412691              Redbridge              1.0
# 124341599             Redbridge              4.0
# 123555122             Redbridge              4.0
# 96635869              Redbridge              4.0
# 120563651             Redbridge              1.0
# 114282032             Redbridge              4.0
# 120859304             Redbridge              4.0
# 123710081             Redbridge              4.0
# 122724968             Redbridge              1.0
# 124034645  Kingston upon Thames              9.0
# 123409187  Kingston upon Thames              4.0
# 123418823  Kingston upon Thames              4.0
# 114255761  Kingston upon Thames              4.0
# 121172195  Kingston upon Thames              4.0
# 122084081  Kingston upon Thames              4.0
# 73509738   Kingston upon Thames              4.0
# 123609983  Kingston upon Thames              9.0
# 120818840  Kingston upon Thames              4.0
# 123966596  Kingston upon Thames              4.0
# 120788990  Kingston upon Thames              4.0
# 120685424  Kingston upon Thames              4.0
# 122440208  Kingston upon Thames              4.0
# 121942022  Kingston upon Thames              4.0
# 122423642  Kingston upon Thames              4.0
# 85715532   Kingston upon Thames              4.0
# 101942609  Kingston upon Thames              4.0
# 84845169   Kingston upon Thames              4.0
# 120335105  Kingston upon Thames              4.0
# 85320837   Kingston upon Thames              4.0
# 123420218  Kingston upon Thames              4.0
# 118579607  Kingston upon Thames              4.0
# 84861576   Kingston upon Thames              4.0
# 120873797  Kingston upon Thames              4.0
#
# [50 rows x 75 columns]

# %%
df_original['coarse_compass_direction'] = df_original["address.outcode"].str.extract("([a-zA-Z]+)")
#df_original['type'] = df_original["Description"].str.extract("(house|apartment|flat|maisonette)")
df_original['sq_ft'] = df_original["size"].str.extract("(\d*) sq. ft.")
#df_original['hold_type2'] = df_original["hold_type"].str.replace("Tenure:","").str.strip()

df_original
# Out:
#                                  Description     Price  \
# ids
# 124059707            3 bedroom flat for sale  325000.0
# 124056446            1 bedroom flat for sale  225000.0
# 124059386            1 bedroom flat for sale  225000.0
# 85324458        1 bedroom apartment for sale  225000.0
# 113260523            1 bedroom flat for sale  225000.0
# ...                                      ...       ...
# 124095956  2 bedroom terraced house for sale  485000.0
# 121881878  2 bedroom terraced house for sale  490000.0
# 124103096  4 bedroom terraced house for sale  510000.0
# 124101830  2 bedroom terraced house for sale  550000.0
# 124087706  3 bedroom terraced house for sale  550000.0
#
#                                                     add_info  \
# ids
# 124059707          Added on 18/06/2022 by haart, Barkingside
# 124056446     Added on 18/06/2022 by Ideal Locations, Ilford
# 124059386     Added on 18/06/2022 by Ideal Locations, Ilford
# 85324458                Added on 17/05/2022 by haart, Ilford
# 113260523  Reduced on 11/11/2021 by Sandra Davidson Estat...
# ...                                                      ...
# 124095956                                                  3
# 121881878                                                  3
# 124103096                                                  3
# 124101830                                                  3
# 124087706                                                  3
#
#            distance_to_any_train       type  bedrooms  bathrooms  \
# ids
# 124059707                    0.5       Flat       3.0        1.0
# 124056446                    0.1       Flat       1.0        1.0
# 124059386                    0.3       Flat       1.0        1.0
# 85324458                     0.9  Apartment       1.0        1.0
# 113260523                    0.4       Flat       1.0        1.0
# ...                          ...        ...       ...        ...
# 124095956                    0.2   Terraced       2.0        1.0
# 121881878                    0.7   Terraced       2.0        1.0
# 124103096                    0.6   Terraced       4.0        2.0
# 124101830                    0.3   Terraced       2.0        1.0
# 124087706                    0.6   Terraced       3.0        1.0
#
#                               size  \
# ids
# 124059707                      NaN
# 124056446                      NaN
# 124059386                      NaN
# 85324458                       NaN
# 113260523                      NaN
# ...                            ...
# 124095956                      NaN
# 121881878                      NaN
# 124103096  793 sq. ft.;(74 sq. m.)
# 124101830                      NaN
# 124087706                      NaN
#
#                                                bullet_points  \
# ids
# 124059707  2-3 Bedrooms;First Floor Flat;Well Presented T...
# 124056446  Great Condition;Perfect for a FTB;Close to Exc...
# 124059386  1 Bedroom Flat;Excellent condition;Close to Lo...
# 85324458   Purpose Built Second Floor Flat;Double Bedroom...
# 113260523  EPC RATING C;Duplex Flat;One bedroom;Lounge;Ki...
# ...                                                      ...
# 124095956  Two Double Bedrooms;Period Terrace House;Super...
# 121881878  Two Good Size Bedrooms;Bright Reception Room;S...
# 124103096  Attractive 2 storey townhouse;Lovely reception...
# 124101830  Freehold;Immaculate condition;South facing gar...
# 124087706  -\tModern Kitchen/Breakfast Room;-\tPeriod Fea...
#
#                                                 station_info  ...  \
# ids                                                           ...
# 124059707  [(0.5, 'Gants Hill Station', 'svg-underground'...  ...
# 124056446  [(0.1, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 124059386  [(0.3, 'Goodmayes Station', 'svg-nationalrail'...  ...
# 85324458   [(0.9, 'Barking Station', 'svg-nationalrail;sv...  ...
# 113260523  [(0.4, 'Seven Kings Station', 'svg-nationalrai...  ...
# ...                                                      ...  ...
# 124095956  [(0.2, 'Selhurst Station', 'svg-nationalrail')...  ...
# 121881878  [(0.7, 'New Southgate Station', 'svg-nationalr...  ...
# 124103096  [(0.6, 'Prince Regent Station', 'svg-dlr'), (0...  ...
# 124101830  [(0.3, 'Tooting Broadway Station', 'svg-underg...  ...
# 124087706  [(0.6, 'Plumstead Station', 'svg-nationalrail'...  ...
#
#           analyticsProperty.propertySubType analyticsProperty.propertyType  \
# ids
# 124059707                              Flat             Flats / Apartments
# 124056446                              Flat             Flats / Apartments
# 124059386                              Flat             Flats / Apartments
# 85324458                          Apartment             Flats / Apartments
# 113260523                              Flat             Flats / Apartments
# ...                                     ...                            ...
# 124095956                          Terraced                         Houses
# 121881878                          Terraced                         Houses
# 124103096                          Terraced                         Houses
# 124101830                          Terraced                         Houses
# 124087706                          Terraced                         Houses
#
#           analyticsProperty.retirement analyticsProperty.soldSTC  \
# ids
# 124059707                        False                     False
# 124056446                        False                      True
# 124059386                        False                      True
# 85324458                         False                      True
# 113260523                        False                      True
# ...                                ...                       ...
# 124095956                        False                     False
# 121881878                        False                     False
# 124103096                        False                     False
# 124101830                        False                     False
# 124087706                        False                     False
#
#           analyticsProperty.videoProvider analyticsProperty.viewType  \
# ids
# 124059707                        No Video                    Current
# 124056446                        No Video                    Current
# 124059386                        No Video                    Current
# 85324458                         No Video                    Current
# 113260523                        No Video                    Current
# ...                                   ...                        ...
# 124095956                   External Link                    Current
# 121881878                        No Video                    Current
# 124103096                   External Link                    Current
# 124101830                        No Video                    Current
# 124087706                        No Video                    Current
#
#            borough_name floorplan_count coarse_compass_direction  sq_ft
# ids
# 124059707     Redbridge             4.0                       IG    NaN
# 124056446     Redbridge             1.0                       IG    NaN
# 124059386     Redbridge             1.0                       IG    NaN
# 85324458      Redbridge             4.0                       IG    NaN
# 113260523     Redbridge             4.0                       IG    NaN
# ...                 ...             ...                      ...    ...
# 124095956  London (all)             4.0                       SE    NaN
# 121881878  London (all)             4.0                        N    NaN
# 124103096  London (all)             9.0                        E    793
# 124101830  London (all)             4.0                       SW    NaN
# 124087706  London (all)             4.0                       SE    NaN
#
# [8859 rows x 77 columns]

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8859 entries, 124059707 to 124087706
# Data columns (total 77 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Description                         8859 non-null   object
#  1   Price                               8859 non-null   float64
#  2   add_info                            8859 non-null   object
#  3   distance_to_any_train               8859 non-null   float64
#  4   type                                8859 non-null   object
#  5   bedrooms                            8859 non-null   float64
#  6   bathrooms                           8859 non-null   float64
#  7   size                                1568 non-null   object
#  8   bullet_points                       8859 non-null   object
#  9   station_info                        8859 non-null   object
#  10  short_description                   8859 non-null   object
#  11  long_description                    8859 non-null   object
#  12  virtualTours                        8859 non-null   object
#  13  rooms                               8859 non-null   object
#  14  nearestAirports                     8859 non-null   object
#  15  nearestStations                     8859 non-null   object
#  16  showSchoolInfo                      8859 non-null   object
#  17  channel                             8859 non-null   object
#  18  sizings                             8859 non-null   object
#  19  bedrooms_model                      8859 non-null   float64
#  20  bathrooms_model                     8859 non-null   float64
#  21  transactionType                     8859 non-null   object
#  22  tags                                8859 non-null   object
#  23  infoReelItems                       8859 non-null   object
#  24  soldPropertyType                    8859 non-null   object
#  25  propertySubType                     8859 non-null   object
#  26  businessForSale                     8859 non-null   object
#  27  commercial                          8859 non-null   object
#  28  commercialUseClasses                8859 non-null   object
#  29  status.published                    8859 non-null   object
#  30  status.archived                     8859 non-null   object
#  31  prices.primaryPrice                 8859 non-null   object
#  32  address.outcode                     8859 non-null   object
#  33  location.latitude                   8859 non-null   float64
#  34  location.longitude                  8859 non-null   float64
#  35  listingHistory.listingUpdateReason  8859 non-null   object
#  36  tenure.tenureType                   8859 non-null   object
#  37  sharedOwnership.sharedOwnership     8859 non-null   object
#  38  sharedOwnership.rentFrequency       8859 non-null   object
#  39  livingCosts.councilTaxExempt        8859 non-null   object
#  40  livingCosts.councilTaxIncluded      8859 non-null   object
#  41  analyticsBranch.agentType           8859 non-null   object
#  42  analyticsBranch.branchId            8859 non-null   float64
#  43  analyticsBranch.branchName          8859 non-null   object
#  44  analyticsBranch.brandName           8859 non-null   object
#  45  analyticsBranch.companyName         8859 non-null   object
#  46  analyticsBranch.companyTradingName  8859 non-null   object
#  47  analyticsBranch.companyType         8859 non-null   object
#  48  analyticsBranch.pageType            8859 non-null   object
#  49  analyticsProperty.added             8859 non-null   float64
#  50  analyticsProperty.auctionOnly       8859 non-null   object
#  51  analyticsProperty.beds              8859 non-null   float64
#  52  analyticsProperty.businessForSale   8859 non-null   object
#  53  analyticsProperty.country           8859 non-null   object
#  54  analyticsProperty.currency          8859 non-null   object
#  55  analyticsProperty.floorplanCount    8859 non-null   float64
#  56  analyticsProperty.furnishedType     8859 non-null   object
#  57  analyticsProperty.hasOnlineViewing  8859 non-null   object
#  58  analyticsProperty.imageCount        8859 non-null   float64
#  59  analyticsProperty.latitude          8859 non-null   float64
#  60  analyticsProperty.longitude         8859 non-null   float64
#  61  analyticsProperty.letAgreed         8859 non-null   object
#  62  analyticsProperty.lettingType       8859 non-null   object
#  63  analyticsProperty.ownership         8859 non-null   object
#  64  analyticsProperty.preOwned          8859 non-null   object
#  65  analyticsProperty.priceQualifier    8859 non-null   object
#  66  analyticsProperty.propertyId        8859 non-null   float64
#  67  analyticsProperty.propertySubType   8859 non-null   object
#  68  analyticsProperty.propertyType      8859 non-null   object
#  69  analyticsProperty.retirement        8859 non-null   object
#  70  analyticsProperty.soldSTC           8859 non-null   object
#  71  analyticsProperty.videoProvider     8859 non-null   object
#  72  analyticsProperty.viewType          8859 non-null   object
#  73  borough_name                        8859 non-null   object
#  74  floorplan_count                     8859 non-null   float64
#  75  coarse_compass_direction            8859 non-null   object
#  76  sq_ft                               1568 non-null   object
# dtypes: float64(17), object(60)
# memory usage: 5.3+ MB

# %%
df_original["sq_ft"] = pd.to_numeric(df_original["sq_ft"], 'coerce').fillna(-1).astype(int)
#df_original["Price"] = pd.to_numeric(df_original["Price"], 'coerce').fillna(-1).astype(int)

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8859 entries, 124059707 to 124087706
# Data columns (total 77 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Description                         8859 non-null   object
#  1   Price                               8859 non-null   float64
#  2   add_info                            8859 non-null   object
#  3   distance_to_any_train               8859 non-null   float64
#  4   type                                8859 non-null   object
#  5   bedrooms                            8859 non-null   float64
#  6   bathrooms                           8859 non-null   float64
#  7   size                                1568 non-null   object
#  8   bullet_points                       8859 non-null   object
#  9   station_info                        8859 non-null   object
#  10  short_description                   8859 non-null   object
#  11  long_description                    8859 non-null   object
#  12  virtualTours                        8859 non-null   object
#  13  rooms                               8859 non-null   object
#  14  nearestAirports                     8859 non-null   object
#  15  nearestStations                     8859 non-null   object
#  16  showSchoolInfo                      8859 non-null   object
#  17  channel                             8859 non-null   object
#  18  sizings                             8859 non-null   object
#  19  bedrooms_model                      8859 non-null   float64
#  20  bathrooms_model                     8859 non-null   float64
#  21  transactionType                     8859 non-null   object
#  22  tags                                8859 non-null   object
#  23  infoReelItems                       8859 non-null   object
#  24  soldPropertyType                    8859 non-null   object
#  25  propertySubType                     8859 non-null   object
#  26  businessForSale                     8859 non-null   object
#  27  commercial                          8859 non-null   object
#  28  commercialUseClasses                8859 non-null   object
#  29  status.published                    8859 non-null   object
#  30  status.archived                     8859 non-null   object
#  31  prices.primaryPrice                 8859 non-null   object
#  32  address.outcode                     8859 non-null   object
#  33  location.latitude                   8859 non-null   float64
#  34  location.longitude                  8859 non-null   float64
#  35  listingHistory.listingUpdateReason  8859 non-null   object
#  36  tenure.tenureType                   8859 non-null   object
#  37  sharedOwnership.sharedOwnership     8859 non-null   object
#  38  sharedOwnership.rentFrequency       8859 non-null   object
#  39  livingCosts.councilTaxExempt        8859 non-null   object
#  40  livingCosts.councilTaxIncluded      8859 non-null   object
#  41  analyticsBranch.agentType           8859 non-null   object
#  42  analyticsBranch.branchId            8859 non-null   float64
#  43  analyticsBranch.branchName          8859 non-null   object
#  44  analyticsBranch.brandName           8859 non-null   object
#  45  analyticsBranch.companyName         8859 non-null   object
#  46  analyticsBranch.companyTradingName  8859 non-null   object
#  47  analyticsBranch.companyType         8859 non-null   object
#  48  analyticsBranch.pageType            8859 non-null   object
#  49  analyticsProperty.added             8859 non-null   float64
#  50  analyticsProperty.auctionOnly       8859 non-null   object
#  51  analyticsProperty.beds              8859 non-null   float64
#  52  analyticsProperty.businessForSale   8859 non-null   object
#  53  analyticsProperty.country           8859 non-null   object
#  54  analyticsProperty.currency          8859 non-null   object
#  55  analyticsProperty.floorplanCount    8859 non-null   float64
#  56  analyticsProperty.furnishedType     8859 non-null   object
#  57  analyticsProperty.hasOnlineViewing  8859 non-null   object
#  58  analyticsProperty.imageCount        8859 non-null   float64
#  59  analyticsProperty.latitude          8859 non-null   float64
#  60  analyticsProperty.longitude         8859 non-null   float64
#  61  analyticsProperty.letAgreed         8859 non-null   object
#  62  analyticsProperty.lettingType       8859 non-null   object
#  63  analyticsProperty.ownership         8859 non-null   object
#  64  analyticsProperty.preOwned          8859 non-null   object
#  65  analyticsProperty.priceQualifier    8859 non-null   object
#  66  analyticsProperty.propertyId        8859 non-null   float64
#  67  analyticsProperty.propertySubType   8859 non-null   object
#  68  analyticsProperty.propertyType      8859 non-null   object
#  69  analyticsProperty.retirement        8859 non-null   object
#  70  analyticsProperty.soldSTC           8859 non-null   object
#  71  analyticsProperty.videoProvider     8859 non-null   object
#  72  analyticsProperty.viewType          8859 non-null   object
#  73  borough_name                        8859 non-null   object
#  74  floorplan_count                     8859 non-null   float64
#  75  coarse_compass_direction            8859 non-null   object
#  76  sq_ft                               8859 non-null   int64
# dtypes: float64(17), int64(1), object(59)
# memory usage: 5.3+ MB

# %%
df_original.describe()
# Out:
#                Price  distance_to_any_train     bedrooms    bathrooms  \
# count    8859.000000            8859.000000  8859.000000  8859.000000
# mean   409328.245287               0.449057     1.852128     1.176205
# std    138290.820690               0.368621     0.800506     0.431847
# min     88750.000000               0.000000     1.000000     1.000000
# 25%    315000.000000               0.200000     1.000000     1.000000
# 50%    399995.000000               0.400000     2.000000     1.000000
# 75%    500000.000000               0.600000     2.000000     1.000000
# max    900000.000000              12.900000     8.000000    16.000000
#
#        bedrooms_model  bathrooms_model  location.latitude  location.longitude  \
# count     8859.000000      8859.000000        8859.000000         8859.000000
# mean         1.852128         1.176205          51.529616           -0.158780
# std          0.800506         0.431847           0.070626            0.174612
# min          1.000000         1.000000          51.300120           -0.498166
# 25%          1.000000         1.000000          51.488934           -0.302180
# 50%          2.000000         1.000000          51.533054           -0.153418
# 75%          2.000000         1.000000          51.581933           -0.054601
# max          8.000000        16.000000          51.683060            0.271164
#
#        analyticsBranch.branchId  analyticsProperty.added  \
# count               8859.000000             8.859000e+03
# mean               89543.283215             2.021824e+07
# std                76597.474305             4.697742e+03
# min                  339.000000             2.016122e+07
# 25%                22316.000000             2.022012e+07
# 50%                68735.000000             2.022040e+07
# 75%               148607.000000             2.022052e+07
# max               248933.000000             2.022070e+07
#
#        analyticsProperty.beds  analyticsProperty.floorplanCount  \
# count             8859.000000                       8859.000000
# mean                 1.852128                          1.027430
# std                  0.800506                          0.409077
# min                  1.000000                          0.000000
# 25%                  1.000000                          1.000000
# 50%                  2.000000                          1.000000
# 75%                  2.000000                          1.000000
# max                  8.000000                         16.000000
#
#        analyticsProperty.imageCount  analyticsProperty.latitude  \
# count                   8859.000000                 8859.000000
# mean                      11.585619                   51.529616
# std                        4.658559                    0.070626
# min                        0.000000                   51.300120
# 25%                        8.000000                   51.488934
# 50%                       11.000000                   51.533054
# 75%                       14.000000                   51.581933
# max                       44.000000                   51.683060
#
#        analyticsProperty.longitude  analyticsProperty.propertyId  \
# count                  8859.000000                  8.859000e+03
# mean                     -0.158780                  1.142164e+08
# std                       0.174612                  1.405718e+07
# min                      -0.498166                  5.284596e+07
# 25%                      -0.302180                  1.141923e+08
# 50%                      -0.153418                  1.207641e+08
# 75%                      -0.054601                  1.230695e+08
# max                       0.271164                  1.245975e+08
#
#        floorplan_count        sq_ft
# count      8859.000000  8859.000000
# mean          4.242240   106.941303
# std           1.707505   247.613100
# min           1.000000    -1.000000
# 25%           4.000000    -1.000000
# 50%           4.000000    -1.000000
# 75%           4.000000    -1.000000
# max          64.000000   999.000000

# %%
#df_original.columns
df_original['coarse_compass_direction']
# Out:
# ids
# 124059707    IG
# 124056446    IG
# 124059386    IG
# 85324458     IG
# 113260523    IG
#              ..
# 124095956    SE
# 121881878     N
# 124103096     E
# 124101830    SW
# 124087706    SE
# Name: coarse_compass_direction, Length: 8859, dtype: object

# %%
# Using pairplot we'll visualize the data for correlation

#sns.pairplot(df_original, x_vars=['bedrooms', 'postcode','type'],
#plt.figure(figsize=(20,15))
#sns.pairplot(df_original, x_vars=['bedrooms', 'bathrooms','compass','type','Station_Prox','hold_type2','sq_ft','Price','borough'], y_vars='Price', height=4, aspect=4, kind='scatter')
sns.pairplot(df_original, x_vars=['bedrooms', 'bathrooms'], y_vars='Price', height=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(df_original, x_vars=['distance_to_any_train','sq_ft'], y_vars='Price', height=4, aspect=1, kind='scatter')
plt.show()

sns.pairplot(df_original, y_vars=['analyticsProperty.propertySubType','tenure.tenureType'], x_vars='Price', height=4, aspect=2, kind='scatter') #,rotation=60)
plt.show()

sns.pairplot(df_original, y_vars=['borough_name','coarse_compass_direction'], x_vars='Price', height=4, aspect=2, kind='scatter')
plt.show()

sns.pairplot(df_original, y_vars=['Price'], x_vars='Price', height=4, aspect=2, kind='scatter')
plt.show()

# %%
sns.pairplot(df_original[df_original['bedrooms'] == 2], x_vars=['distance_to_any_train'], y_vars='Price', size=7, aspect=1, kind='scatter')
plt.show()
# Out:
# /home/guava/Springboard/capstone_prework/venv/lib/python3.8/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df_original[df_original["analyticsProperty.propertyType"] == "Houses"], x_vars=['bedrooms', 'coarse_compass_direction'],
             y_vars='Price', height=5, aspect=1, kind='scatter')
plt.show()

# %%
df_original.hist(figsize=(12,12))
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'distance_to_any_train'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'bedrooms_model'}>,
#         <AxesSubplot:title={'center':'bathrooms_model'}>,
#         <AxesSubplot:title={'center':'location.latitude'}>,
#         <AxesSubplot:title={'center':'location.longitude'}>],
#        [<AxesSubplot:title={'center':'analyticsBranch.branchId'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.added'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.beds'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.floorplanCount'}>],
#        [<AxesSubplot:title={'center':'analyticsProperty.imageCount'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.latitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.longitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.propertyId'}>],
#        [<AxesSubplot:title={'center':'floorplan_count'}>,
#         <AxesSubplot:title={'center':'sq_ft'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_original.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'distance_to_any_train'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'bedrooms_model'}>,
#         <AxesSubplot:title={'center':'bathrooms_model'}>,
#         <AxesSubplot:title={'center':'location.latitude'}>,
#         <AxesSubplot:title={'center':'location.longitude'}>],
#        [<AxesSubplot:title={'center':'analyticsBranch.branchId'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.added'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.beds'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.floorplanCount'}>],
#        [<AxesSubplot:title={'center':'analyticsProperty.imageCount'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.latitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.longitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.propertyId'}>],
#        [<AxesSubplot:title={'center':'floorplan_count'}>,
#         <AxesSubplot:title={'center':'sq_ft'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_original[(df_original['sq_ft'] != -1) & (df_original['Price'] != -1)].hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'distance_to_any_train'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>],
#        [<AxesSubplot:title={'center':'bedrooms_model'}>,
#         <AxesSubplot:title={'center':'bathrooms_model'}>,
#         <AxesSubplot:title={'center':'location.latitude'}>,
#         <AxesSubplot:title={'center':'location.longitude'}>],
#        [<AxesSubplot:title={'center':'analyticsBranch.branchId'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.added'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.beds'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.floorplanCount'}>],
#        [<AxesSubplot:title={'center':'analyticsProperty.imageCount'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.latitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.longitude'}>,
#         <AxesSubplot:title={'center':'analyticsProperty.propertyId'}>],
#        [<AxesSubplot:title={'center':'floorplan_count'}>,
#         <AxesSubplot:title={'center':'sq_ft'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_original["coarse_compass_direction"].value_counts()
# Out:
# N     1457
# W     1198
# SE     943
# UB     856
# HA     747
# RM     627
# NW     514
# EN     444
# TW     436
# E      378
# BR     314
# KT     304
# SW     223
# CR     177
# IG     125
# EC      72
# WC      23
# TN      16
# DA       2
# WD       2
# HP       1
# Name: coarse_compass_direction, dtype: int64

# %%
df_original["analyticsProperty.propertyType"].value_counts()
# Out:
# Flats / Apartments    7187
# Houses                1578
# Bungalows               94
# Name: analyticsProperty.propertyType, dtype: int64

# %%
df_original["analyticsProperty.propertySubType"].value_counts()
# Out:
# Flat                      3659
# Apartment                 2702
# Terraced                   727
# Maisonette                 585
# Semi-Detached              431
# End of Terrace             274
# Ground Flat                140
# House                       72
# Bungalow                    44
# Ground Maisonette           43
# Semi-Detached Bungalow      35
# Detached                    33
# Town House                  23
# Duplex                      18
# Penthouse                   16
# Detached Bungalow           15
# Cottage                     14
# Block of Apartments         12
# Hotel Room                  11
# Mews                         2
# Coach House                  1
# Link Detached House          1
# Chalet                       1
# Name: analyticsProperty.propertySubType, dtype: int64

# %%
# for each in df_original.columns:
#
#     if each not in ['other_key_info','bullet_points','station_info','long_description','add_info']:
#         print(each)
#         print(df_original[each].value_counts())

# %%
df_original.iloc[:,:-1].shape,df_original.iloc[:,-1].shape,df_original["Price"].shape
# Out:
# ((8859, 76), (8859,), (8859,))
