# %%
import sys

sys.path.append('../../globalfunction')  # setting path
import globalfunction.vv as vv  # importing
import globalfunction.pp as pp  # importing

import pandas as pd

df_original = vv.quick_data(publish=True)
df_original.head(50)
# Out:
# remove duplicates: 20925/29984/22089/24047 ==> 20925/20520/18445/20297
# dataframe length: 20255
# allowing Price to pass with 38 nulls/NANs
# allowing add_info to pass with 2442 nulls/NANs
# allowing date_scraped to pass with 2442 nulls/NANs
# allowing type to pass with 79 nulls/NANs
# allowing bedrooms to pass with 895 nulls/NANs
# allowing bathrooms to pass with 1373 nulls/NANs
# dropping size because 17070 nulls/NANs is too many
# dropping other_key_info because 20254 nulls/NANs is too many
# allowing bullet_points to pass with 2011 nulls/NANs
# allowing station_info to pass with 1 nulls/NANs
# dropping hold_type because 14905 nulls/NANs is too many
# allowing short_description to pass with 1 nulls/NANs
# allowing long_description to pass with 4 nulls/NANs
# allowing date_scraped_listing to pass with 1 nulls/NANs
# allowing virtualTours to pass with 1880 nulls/NANs
# allowing rooms to pass with 1880 nulls/NANs
# allowing nearestAirports to pass with 1880 nulls/NANs
# allowing nearestStations to pass with 1880 nulls/NANs
# allowing showSchoolInfo to pass with 1880 nulls/NANs
# allowing channel to pass with 1880 nulls/NANs
# allowing sizings to pass with 1880 nulls/NANs
# allowing bedrooms_model to pass with 2547 nulls/NANs
# allowing bathrooms_model to pass with 3093 nulls/NANs
# allowing transactionType to pass with 1880 nulls/NANs
# allowing tags to pass with 1880 nulls/NANs
# allowing infoReelItems to pass with 1880 nulls/NANs
# allowing soldPropertyType to pass with 1880 nulls/NANs
# dropping auctionProvider because 20255 nulls/NANs is too many
# allowing propertySubType to pass with 1880 nulls/NANs
# allowing businessForSale to pass with 1880 nulls/NANs
# allowing commercial to pass with 1880 nulls/NANs
# allowing commercialUseClasses to pass with 1880 nulls/NANs
# dropping affordableBuyingScheme because 20255 nulls/NANs is too many
# allowing status.published to pass with 1880 nulls/NANs
# allowing status.archived to pass with 1880 nulls/NANs
# allowing text.description to pass with 1880 nulls/NANs
# allowing text.propertyPhrase to pass with 1880 nulls/NANs
# allowing text.shareText to pass with 1880 nulls/NANs
# allowing text.shareDescription to pass with 1880 nulls/NANs
# allowing text.pageTitle to pass with 1880 nulls/NANs
# allowing text.shortDescription to pass with 1880 nulls/NANs
# allowing prices.primaryPrice to pass with 1880 nulls/NANs
# dropping prices.secondaryPrice because 20255 nulls/NANs is too many
# dropping prices.displayPriceQualifier because 12288 nulls/NANs is too many
# dropping prices.pricePerSqFt because 17479 nulls/NANs is too many
# dropping prices.exchangeRate because 20255 nulls/NANs is too many
# allowing address.displayAddress to pass with 1880 nulls/NANs
# allowing address.countryCode to pass with 1880 nulls/NANs
# dropping address.deliveryPointId because 8340 nulls/NANs is too many
# allowing address.ukCountry to pass with 1880 nulls/NANs
# allowing address.outcode to pass with 1880 nulls/NANs
# allowing address.incode to pass with 1880 nulls/NANs
# allowing location.latitude to pass with 1880 nulls/NANs
# allowing location.longitude to pass with 1880 nulls/NANs
# allowing location.circleRadiusOnMap to pass with 1880 nulls/NANs
# allowing location.zoomLevel to pass with 1880 nulls/NANs
# allowing location.pinType to pass with 1880 nulls/NANs
# allowing location.showMap to pass with 1880 nulls/NANs
# allowing misInfo.branchId to pass with 1880 nulls/NANs
# dropping misInfo.offerAdvertStampTypeId because 20136 nulls/NANs is too many
# allowing misInfo.premiumDisplay to pass with 1880 nulls/NANs
# dropping misInfo.premiumDisplayStampId because 15717 nulls/NANs is too many
# allowing misInfo.brandPlus to pass with 1880 nulls/NANs
# allowing misInfo.featuredProperty to pass with 1880 nulls/NANs
# allowing dfpAdInfo.channel to pass with 1880 nulls/NANs
# allowing dfpAdInfo.targeting to pass with 1880 nulls/NANs
# allowing listingHistory.listingUpdateReason to pass with 1881 nulls/NANs
# allowing contactInfo.contactMethod to pass with 1880 nulls/NANs
# allowing contactInfo.telephoneNumbers.localNumber to pass with 1884 nulls/NANs
# dropping contactInfo.telephoneNumbers.internationalNumber because 20255 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerText because 20255 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerTitle because 20255 nulls/NANs is too many
# dropping contactInfo.telephoneNumbers.disclaimerDescription because 20255 nulls/NANs is too many
# allowing tenure.tenureType to pass with 3174 nulls/NANs
# dropping tenure.yearsRemainingOnLease because 19052 nulls/NANs is too many
# dropping tenure.message because 18980 nulls/NANs is too many
# allowing sharedOwnership.sharedOwnership to pass with 1880 nulls/NANs
# dropping sharedOwnership.ownershipPercentage because 20249 nulls/NANs is too many
# dropping sharedOwnership.rentPrice because 20254 nulls/NANs is too many
# allowing sharedOwnership.rentFrequency to pass with 4942 nulls/NANs
# allowing livingCosts.councilTaxExempt to pass with 1880 nulls/NANs
# allowing livingCosts.councilTaxIncluded to pass with 1880 nulls/NANs
# dropping livingCosts.annualGroundRent because 20208 nulls/NANs is too many
# dropping livingCosts.groundRentReviewPeriodInYears because 20242 nulls/NANs is too many
# dropping livingCosts.groundRentPercentageIncrease because 20249 nulls/NANs is too many
# dropping livingCosts.annualServiceCharge because 20194 nulls/NANs is too many
# dropping livingCosts.councilTaxBand because 20042 nulls/NANs is too many
# dropping auctionProvider.endDate because 20248 nulls/NANs is too many
# dropping auctionProvider.auctionTimeRemaining because 20248 nulls/NANs is too many
# dropping auctionProvider.bid because 20255 nulls/NANs is too many
# allowing date_scraped_meta to pass with 29 nulls/NANs
# allowing analyticsBranch.agentType to pass with 29 nulls/NANs
# allowing analyticsBranch.branchId to pass with 29 nulls/NANs
# allowing analyticsBranch.branchName to pass with 29 nulls/NANs
# allowing analyticsBranch.brandName to pass with 29 nulls/NANs
# allowing analyticsBranch.companyName to pass with 29 nulls/NANs
# allowing analyticsBranch.companyTradingName to pass with 4578 nulls/NANs
# allowing analyticsBranch.companyType to pass with 29 nulls/NANs
# allowing analyticsBranch.pageType to pass with 29 nulls/NANs
# allowing analyticsProperty.added to pass with 29 nulls/NANs
# allowing analyticsProperty.auctionOnly to pass with 29 nulls/NANs
# allowing analyticsProperty.beds to pass with 29 nulls/NANs
# allowing analyticsProperty.businessForSale to pass with 29 nulls/NANs
# allowing analyticsProperty.country to pass with 29 nulls/NANs
# allowing analyticsProperty.currency to pass with 29 nulls/NANs
# allowing analyticsProperty.floorplanCount to pass with 29 nulls/NANs
# allowing analyticsProperty.furnishedType to pass with 29 nulls/NANs
# allowing analyticsProperty.hasOnlineViewing to pass with 29 nulls/NANs
# allowing analyticsProperty.imageCount to pass with 29 nulls/NANs
# allowing analyticsProperty.latitude to pass with 29 nulls/NANs
# allowing analyticsProperty.longitude to pass with 29 nulls/NANs
# allowing analyticsProperty.letAgreed to pass with 29 nulls/NANs
# allowing analyticsProperty.lettingType to pass with 29 nulls/NANs
# dropping analyticsProperty.maxSizeAc because 17071 nulls/NANs is too many
# dropping analyticsProperty.maxSizeFt because 17071 nulls/NANs is too many
# dropping analyticsProperty.minSizeAc because 17071 nulls/NANs is too many
# dropping analyticsProperty.minSizeFt because 17071 nulls/NANs is too many
# allowing analyticsProperty.ownership to pass with 29 nulls/NANs
# allowing analyticsProperty.preOwned to pass with 29 nulls/NANs
# allowing analyticsProperty.price to pass with 29 nulls/NANs
# allowing analyticsProperty.priceQualifier to pass with 29 nulls/NANs
# allowing analyticsProperty.propertyId to pass with 29 nulls/NANs
# allowing analyticsProperty.propertySubType to pass with 29 nulls/NANs
# allowing analyticsProperty.propertyType to pass with 29 nulls/NANs
# allowing analyticsProperty.retirement to pass with 29 nulls/NANs
# dropping analyticsProperty.selectedCurrency because 20255 nulls/NANs is too many
# allowing analyticsProperty.soldSTC to pass with 29 nulls/NANs
# allowing analyticsProperty.videoProvider to pass with 29 nulls/NANs
# allowing analyticsProperty.viewType to pass with 29 nulls/NANs
# dropping Unnamed: 46 because 20255 nulls/NANs is too many
# allowing floorplan_count to pass with 1880 nulls/NANs
# allowing borough_name to pass with 22 nulls/NANs
#                                        Description     Price  \
# ids
# 124153820            4 bedroom town house for sale  550000.0
# 120604136  3 bedroom end of terrace house for sale  525000.0
# 124368626   3 bedroom semi-detached house for sale  525000.0
# 120157577     3 bedroom detached bungalow for sale  505000.0
# 120379235   3 bedroom semi-detached house for sale  525000.0
# 122798015            3 bedroom maisonette for sale  600000.0
# 85652838                   2 bedroom flat for sale  600000.0
# 122739626             1 bedroom apartment for sale  500000.0
# 120248726             2 bedroom apartment for sale  399950.0
# 123186293             1 bedroom apartment for sale  400000.0
# 118677035                  1 bedroom flat for sale  355000.0
# 120181052                  1 bedroom flat for sale  325000.0
# 114293234                  1 bedroom flat for sale  349950.0
# 124452128             2 bedroom apartment for sale  425000.0
# 120500297             1 bedroom apartment for sale  305000.0
# 123229436             3 bedroom penthouse for sale  285000.0
# 120779345             2 bedroom apartment for sale  600000.0
# 122098883                  2 bedroom flat for sale  600000.0
# 122296673                  2 bedroom flat for sale  600000.0
# 84722637                   2 bedroom flat for sale  600000.0
# 123934121             1 bedroom apartment for sale  600000.0
# 121763024                  1 bedroom flat for sale  600000.0
# 114197282            2 bedroom maisonette for sale  600000.0
# 85463622                   3 bedroom flat for sale  600000.0
# 85656135                   2 bedroom flat for sale  600000.0
# 122381537            2 bedroom maisonette for sale  600000.0
# 122424989             2 bedroom apartment for sale  600000.0
# 116914793             2 bedroom apartment for sale  600000.0
# 121673984             1 bedroom apartment for sale  600000.0
# 118849808             2 bedroom apartment for sale  600000.0
# 120099290             1 bedroom apartment for sale  190000.0
# 122824235             1 bedroom apartment for sale  150000.0
# 107258270             2 bedroom apartment for sale  154000.0
# 123258368                  1 bedroom flat for sale  154975.0
# 116542535                  2 bedroom flat for sale  159000.0
# 124180148             2 bedroom apartment for sale  162000.0
# 115525946                  2 bedroom flat for sale  162500.0
# 124584809             2 bedroom apartment for sale  163000.0
# 124584860             2 bedroom apartment for sale  165000.0
# 123524753             1 bedroom apartment for sale  170000.0
# 124584881             2 bedroom apartment for sale  170000.0
# 123258365                  1 bedroom flat for sale  172975.0
# 124064723        3 bedroom terraced house for sale  450000.0
# 124557605  3 bedroom end of terrace house for sale  500000.0
# 124025066   3 bedroom semi-detached house for sale  500000.0
# 124061165  3 bedroom end of terrace house for sale  450000.0
# 122712446   3 bedroom semi-detached house for sale  450000.0
# 122102135   3 bedroom semi-detached house for sale  450000.0
# 85494801    3 bedroom semi-detached house for sale  425000.0
# 85705701    3 bedroom semi-detached house for sale  450000.0
#
#                                                     add_info  \
# ids
# 124153820  Added on 21/06/2022 by Purplebricks, covering ...
# 120604136        Added on 03/03/2022 by haart, Hayes (Middx)
# 124368626         Added on 27/06/2022 by Coopers, Hillingdon
# 120157577      Reduced on 23/03/2022 by haart, Hayes (Middx)
# 120379235        Added on 25/02/2022 by haart, Hayes (Middx)
# 122798015     Reduced on 13/06/2022 by Foxtons, Notting Hill
# 85652838   Added on 13/06/2022 by Foxtons Auction, Coveri...
# 122739626  Reduced on 10/06/2022 by tlc Estate Agents, Ea...
# 120248726      Reduced on 24/03/2022 by Noahs London, London
# 123186293  Reduced on 15/06/2022 by Savills, Brook Green ...
# 118677035  Reduced on 15/02/2022 by Kinleigh Folkard & Ha...
# 120181052       Added on 18/02/2022 by Foxtons, Notting Hill
# 114293234  Added on 26/04/2022 by Kinleigh Folkard & Hayw...
# 124452128        Added on 29/06/2022 by Noahs London, London
# 120500297             Reduced on 11/04/2022 by haart, Ealing
# 123229436   Added on 11/05/2022 by DBK Estate Agents, Heston
# 120779345  Added on 08/03/2022 by Purplebricks, covering ...
# 122098883   Added on 07/04/2022 by Hamptons Sales, Islington
# 122296673  Added on 12/04/2022 by Kinleigh Folkard & Hayw...
# 84722637           Added on 29/04/2022 by Nested, Nationwide
# 123934121  Added on 15/06/2022 by NEILSON & BAUER LTD, Is...
# 121763024   Added on 30/03/2022 by Hamptons Sales, Islington
# 114197282  Reduced on 16/06/2022 by Purplebricks, coverin...
# 85463622   Reduced on 01/06/2022 by Kinleigh Folkard & Ha...
# 85656135        Added on 13/06/2022 by Butler & Stag, London
# 122381537  Added on 13/04/2022 by Drivers & Norris, Islin...
# 122424989  Added on 14/04/2022 by Marsh & Parsons, Islington
# 116914793  Reduced on 23/12/2021 by Marsh & Parsons, Isli...
# 121673984  Reduced on 09/05/2022 by Stirling Ackroyd, Cle...
# 118849808  Added on 18/01/2022 by Purplebricks, covering ...
# 120099290  Reduced on 08/03/2022 by Parkfields Estates, S...
# 122824235  Added on 26/04/2022 by Chase Buchanan, Islewor...
# 107258270        Added on 19/05/2021 by haart, Hayes (Middx)
# 123258368  Reduced on 11/05/2022 by Foxtons New Homes, Lo...
# 116542535     Added on 18/11/2021 by Barnard Marcus, Feltham
# 124180148                     Added on 22/06/2022 by FABRICA
# 115525946           Added on 29/10/2021 by Shaw & Co, Heston
# 124584809                     Added on 01/07/2022 by FABRICA
# 124584860                     Added on 01/07/2022 by FABRICA
# 123524753         Added on 11/02/2022 by Winkworth, Chiswick
# 124584881                     Added on 01/07/2022 by FABRICA
# 123258365  Reduced on 11/05/2022 by Foxtons New Homes, Lo...
# 124064723              Added on 18/06/2022 by haart, Romford
# 124557605  Reduced on 23/05/2022 by Stonebridge Estates, ...
# 124025066     Added on 17/03/2022 by haart, covering Rainham
# 124061165     Added on 18/06/2022 by haart, covering Rainham
# 122712446              Added on 22/04/2022 by Strike, London
# 122102135  Added on 07/04/2022 by PATTERSON HAWTHORN, Rai...
# 85494801           Added on 08/06/2022 by haart, Harold Wood
# 85705701        Added on 14/06/2022 by haart, Chadwell Heath
#
#            distance_to_any_train               type  bedrooms  bathrooms  \
# ids
# 124153820                    0.9         Town House       4.0        1.0
# 120604136                    0.3     End of Terrace       3.0        2.0
# 124368626                    0.9      Semi-Detached       3.0        1.0
# 120157577                    1.4  Detached Bungalow       3.0        1.0
# 120379235                    0.7      Semi-Detached       3.0        1.0
# 122798015                    0.5         Maisonette       3.0        1.0
# 85652838                     0.1               Flat       2.0        1.0
# 122739626                    0.3          Apartment       1.0        1.0
# 120248726                    0.5          Apartment       2.0        1.0
# 123186293                    0.2          Apartment       1.0        1.0
# 118677035                    0.2               Flat       1.0        1.0
# 120181052                    0.5               Flat       1.0        1.0
# 114293234                    0.2               Flat       1.0        1.0
# 124452128                    0.5          Apartment       2.0        1.0
# 120500297                    0.5          Apartment       1.0        1.0
# 123229436                    0.8          Penthouse       3.0        2.0
# 120779345                    0.1          Apartment       2.0        1.0
# 122098883                    0.2               Flat       2.0        1.0
# 122296673                    0.1               Flat       2.0        2.0
# 84722637                     0.4               Flat       2.0        1.0
# 123934121                    0.1          Apartment       1.0        1.0
# 121763024                    0.2               Flat       1.0        1.0
# 114197282                    0.2         Maisonette       2.0        1.0
# 85463622                     0.2               Flat       3.0        1.0
# 85656135                     0.3               Flat       2.0        1.0
# 122381537                    0.3         Maisonette       2.0        1.0
# 122424989                    0.1          Apartment       2.0        1.0
# 116914793                    0.1          Apartment       2.0        1.0
# 121673984                    0.4          Apartment       1.0        1.0
# 118849808                    0.1          Apartment       2.0        1.0
# 120099290                    0.3          Apartment       1.0        1.0
# 122824235                    0.3          Apartment       1.0        1.0
# 107258270                    0.3          Apartment       2.0        1.0
# 123258368                    0.1               Flat       1.0        1.0
# 116542535                    0.2               Flat       2.0        1.0
# 124180148                    0.1          Apartment       2.0        2.0
# 115525946                    0.8               Flat       2.0        2.0
# 124584809                    0.1          Apartment       2.0        2.0
# 124584860                    0.1          Apartment       2.0        2.0
# 123524753                    0.1          Apartment       1.0        1.0
# 124584881                    0.1          Apartment       2.0        2.0
# 123258365                    0.1               Flat       1.0        1.0
# 124064723                    1.2           Terraced       3.0        1.0
# 124557605                    1.0     End of Terrace       3.0        1.0
# 124025066                    1.1      Semi-Detached       3.0        1.0
# 124061165                    0.8     End of Terrace       3.0        1.0
# 122712446                    0.7      Semi-Detached       3.0        1.0
# 122102135                    0.7      Semi-Detached       3.0        2.0
# 85494801                     1.6      Semi-Detached       3.0        1.0
# 85705701                     0.8      Semi-Detached       3.0        2.0
#
#                                                bullet_points  \
# ids
# 124153820  Four Bedrooms;Spacious And Light-Filled Accomm...
# 120604136  Hayes Town;End terrace;Three bedrooms, two bat...
# 124368626  Three bedroom house;End of terrace;Oak Farm;No...
# 120157577  Hillingdon;Detached bungalow;Three bedrooms;Bl...
# 120379235  Hayes Town;Semi detached;Three bedrooms;A1 con...
# 122798015  Wonderful 3 bedroom duplex flat;Bright recepti...
# 85652838   Superb 2 bedroom apartment;Good size reception...
# 122739626  1 Bathroom;1 Bedroom;1 Reception Room;Flat/Apa...
# 120248726  Two Bedroom | One Bathroom;Unmodernised | Peri...
# 123186293  Approximately 250 yards to Shepherds Bush stat...
# 118677035  One bedroom ;One bathroom;Period building ;Thi...
# 120181052  Bright and well-arranged 1 bedroom flat;Set on...
# 114293234  Large studio;Separate bathroom;Separate kitche...
# 124452128  Two Bedroom | One Bathroom;First Floor | Perio...
# 120500297  One Double Bedroom;Great Size Reception Room;S...
# 123229436  Penthouse Apartment;Cash Buyers Only;Three Bed...
# 120779345  Beautiful Two Double Bedroom Fifth Floor Apart...
# 122098883  Two Bedrooms;Upper Floor;South Facing Communal...
# 122296673  Two double bedrooms;18'1 Reception room;Fitted...
# 84722637   Large 2 double bedroomed garden flat;Separate ...
# 123934121  19th Century School Conversion;Great ceiling h...
# 121763024  Extended Period Conversion;Double Bedroom;Open...
# 114197282  Beautiful Two Bedroom Maisonette In Former Pub...
# 85463622   Three bedrooms;17'2 Reception room ;Fitted kit...
# 85656135   Two Double Bedrooms;Private South-Facing Garde...
# 122381537  Split-Level Victorian Conversion;Approximately...
# 122424989  2 Bedrooms;Private Garden;Period;Next to Highb...
# 116914793  2 Bedrooms;Modern;Private Balcony;24 Hour Conc...
# 121673984  *** EWS1 compliant;First floor apartment;Priva...
# 118849808  Stunning Two Double Bedroom Modern Apartment;P...
# 120099290  CASH BUYERS ONLY;SECOND FLOOR;SITUATED ON TOP ...
# 122824235  Viewings accompanied by Chase Buchanan;Stunnin...
# 107258270  SHARED OWNERSHIP;NEW HOME;VIDEO ENTRY SYSTEM;2...
# 123258368  Buy from 50% share of this amazing 1 bed flat;...
# 116542535  SHARED OWNERSHIP.;TWO DOUBLE BEDROOM.;1ST FLOO...
# 124180148  Private balcony;Open plan living;Fully fitted ...
# 115525946  BEING SOLD AS 50% SHARED OWNERSHIP;En suite;No...
# 124584809  Large private balcony;Open plan living;Fully f...
# 124584860  Large private balcony;Open plan living;Fully f...
# 123524753  One bedroom apartment;Riverside development wi...
# 124584881  Large private balcony;Open plan living;Fully f...
# 123258365  Buy from 50% share of this amazing 1 bed flat;...
# 124064723  Off street parking;Garage;Through lounge;Kitch...
# 124557605  Three Bedrooms;Can Be Converted Back Into A Fo...
# 124025066  THREE BEDROOMS;SEMI DETACHED HOUSE;DOUBLE GARA...
# 124061165  Three Bedrooms;Terraced House;Off Street Parki...
# 122712446  Garden;Driveway;Local amenities;Conservatory;P...
# 122102135  GUIDE PRICE £450,000 - £475,000;2012 BUILD THR...
# 85494801   Living Room;Fitted Kitchen;Three Bedrooms;Grou...
# 85705701   THREE BEDROOMS;FIRST FLOOR BATHROOM;OFF STREET...
#
#                                                 station_info  \
# ids
# 124153820  [(0.9, 'Uxbridge Station', 'svg-underground'),...
# 120604136  [(0.3, 'Hayes & Harlington Station', 'svg-nati...
# 124368626  [(0.9, 'Hillingdon Station', 'svg-underground'...
# 120157577  [(1.4, 'West Drayton Station', 'svg-nationalra...
# 120379235  [(0.7, 'Hayes & Harlington Station', 'svg-nati...
# 122798015  [(0.5, 'Ladbroke Grove Station', 'svg-undergro...
# 85652838   [(0.1, 'Earls Court Station', 'svg-underground...
# 122739626  [(0.3, 'West Kensington Station', 'svg-undergr...
# 120248726  [(0.5, 'White City Station', 'svg-underground'...
# 123186293  [(0.2, "Shepherd's Bush (Central) Station", 's...
# 118677035  [(0.2, "Shepherd's Bush (Central) Station", 's...
# 120181052  [(0.5, 'White City Station', 'svg-underground'...
# 114293234  [(0.2, "Shepherd's Bush (Central) Station", 's...
# 124452128  [(0.5, 'White City Station', 'svg-underground'...
# 120500297  [(0.5, 'South Ealing Station', 'svg-undergroun...
# 123229436  [(0.8, 'Southall Station', 'svg-nationalrail')...
# 120779345  [(0.1, 'Drayton Park Station', 'svg-nationalra...
# 122098883  [(0.2, 'Drayton Park Station', 'svg-nationalra...
# 122296673  [(0.1, 'Canonbury Station', 'svg-overground'),...
# 84722637   [(0.4, 'Canonbury Station', 'svg-overground'),...
# 123934121  [(0.1, 'Holloway Road Station', 'svg-undergrou...
# 121763024  [(0.2, 'Essex Road Station', 'svg-nationalrail...
# 114197282  [(0.2, 'Holloway Road Station', 'svg-undergrou...
# 85463622   [(0.2, 'Canonbury Station', 'svg-overground'),...
# 85656135   [(0.3, 'Canonbury Station', 'svg-overground'),...
# 122381537  [(0.3, 'Holloway Road Station', 'svg-undergrou...
# 122424989  [(0.1, 'Drayton Park Station', 'svg-nationalra...
# 116914793  [(0.1, 'Drayton Park Station', 'svg-nationalra...
# 121673984  [(0.4, 'Barbican Station', 'svg-nationalrail;s...
# 118849808  [(0.1, 'Drayton Park Station', 'svg-nationalra...
# 120099290  [(0.3, 'Hounslow Central Station', 'svg-underg...
# 122824235  [(0.3, 'Isleworth Station', 'svg-nationalrail'...
# 107258270  [(0.3, 'Hounslow East Station', 'svg-undergrou...
# 123258368  [(0.1, 'Feltham Station', 'svg-nationalrail'),...
# 116542535  [(0.2, 'Feltham Station', 'svg-nationalrail'),...
# 124180148  [(0.1, 'Hounslow West Station', 'svg-undergrou...
# 115525946  [(0.8, 'Hounslow West Station', 'svg-undergrou...
# 124584809  [(0.1, 'Hounslow West Station', 'svg-undergrou...
# 124584860  [(0.1, 'Hounslow West Station', 'svg-undergrou...
# 123524753  [(0.1, 'Kew Bridge Station', 'svg-nationalrail...
# 124584881  [(0.1, 'Hounslow West Station', 'svg-undergrou...
# 123258365  [(0.1, 'Feltham Station', 'svg-nationalrail'),...
# 124064723  [(1.2, 'Romford Station', 'svg-nationalrail'),...
# 124557605  [(1.0, 'Gidea Park Station', 'svg-nationalrail...
# 124025066  [(1.1, 'Rainham (Essex) Station', 'svg-nationa...
# 124061165  [(0.8, 'Elm Park Station', 'svg-underground'),...
# 122712446  [(0.7, 'Romford Station', 'svg-nationalrail'),...
# 122102135  [(0.7, 'Rainham (Essex) Station', 'svg-nationa...
# 85494801   [(1.6, 'Harold Wood Station', 'svg-nationalrai...
# 85705701   [(0.8, 'Chadwell Heath Station', 'svg-national...
#
#                                            short_description  ...  \
# ids                                                           ...
# 124153820          svg-camera=19;;svg-floorplan=1;;Read more  ...
# 120604136  SOLD STC;;svg-camera=9;;svg-floorplan=1;;Read ...  ...
# 124368626          svg-camera=10;;svg-floorplan=1;;Read more  ...
# 120157577          svg-camera=12;;svg-floorplan=1;;Read more  ...
# 120379235  SOLD STC;;svg-camera=11;;svg-floorplan=2;;Read...  ...
# 122798015           svg-camera=8;;svg-floorplan=2;;Read more  ...
# 85652838            svg-camera=8;;svg-floorplan=2;;Read more  ...
# 122739626           svg-camera=7;;svg-floorplan=1;;Read more  ...
# 120248726  SOLD STC;;svg-camera=7;;svg-floorplan=1;;Read ...  ...
# 123186293  UNDER OFFER;;svg-camera=6;;svg-floorplan=1;;Re...  ...
# 118677035           svg-camera=9;;svg-floorplan=1;;Read more  ...
# 120181052           svg-camera=4;;svg-floorplan=2;;Read more  ...
# 114293234          svg-camera=10;;svg-floorplan=1;;Read more  ...
# 124452128           svg-camera=7;;svg-floorplan=1;;Read more  ...
# 120500297           svg-camera=4;;svg-floorplan=1;;Read more  ...
# 123229436           svg-camera=9;;svg-floorplan=1;;Read more  ...
# 120779345          svg-camera=40;;svg-floorplan=1;;Read more  ...
# 122098883  UNDER OFFER;;svg-camera=16;;svg-floorplan=1;;R...  ...
# 122296673  UNDER OFFER;;svg-camera=16;;svg-floorplan=1;;R...  ...
# 84722637   SOLD STC;;svg-camera=9;;svg-floorplan=1;;Read ...  ...
# 123934121          svg-camera=20;;svg-floorplan=1;;Read more  ...
# 121763024  UNDER OFFER;;svg-camera=22;;svg-floorplan=1;;R...  ...
# 114197282          svg-camera=15;;svg-floorplan=1;;Read more  ...
# 85463622            svg-camera=6;;svg-floorplan=1;;Read more  ...
# 85656135   ONLINE VIEWING;;svg-camera=17;;svg-virtual-tou...  ...
# 122381537  SOLD STC;;svg-camera=13;;svg-floorplan=1;;Read...  ...
# 122424989  UNDER OFFER;;svg-camera=6;;svg-floorplan=1;;Re...  ...
# 116914793  NEW HOME;;SOLD STC;;svg-camera=6;;svg-floorpla...  ...
# 121673984  svg-camera=17;;svg-virtual-tour=1;;svg-floorpl...  ...
# 118849808          svg-camera=15;;svg-floorplan=1;;Read more  ...
# 120099290           svg-camera=5;;svg-floorplan=1;;Read more  ...
# 122824235  SOLD STC;;svg-camera=13;;svg-floorplan=1;;Read...  ...
# 107258270  NEW HOME;;svg-camera=14;;svg-floorplan=1;;Read...  ...
# 123258368  NEW HOME;;svg-camera=17;;svg-floorplan=1;;Read...  ...
# 116542535           svg-camera=9;;svg-floorplan=1;;Read more  ...
# 124180148  NEW HOME;;svg-camera=9;;svg-floorplan=1;;Read ...  ...
# 115525946  SOLD STC;;svg-camera=8;;svg-virtual-tour=1;;sv...  ...
# 124584809  NEW HOME;;svg-camera=17;;svg-floorplan=1;;Read...  ...
# 124584860  NEW HOME;;svg-camera=17;;svg-floorplan=1;;Read...  ...
# 123524753          svg-camera=14;;svg-floorplan=1;;Read more  ...
# 124584881  NEW HOME;;svg-camera=17;;svg-floorplan=1;;Read...  ...
# 123258365  NEW HOME;;svg-camera=17;;svg-floorplan=1;;Read...  ...
# 124064723                            svg-camera=7;;Read more  ...
# 124557605          svg-camera=13;;svg-floorplan=1;;Read more  ...
# 124025066                           svg-camera=17;;Read more  ...
# 124061165          svg-camera=17;;svg-floorplan=1;;Read more  ...
# 122712446  SOLD STC;;svg-camera=11;;svg-floorplan=2;;Read...  ...
# 122102135  SOLD STC;;svg-camera=12;;svg-floorplan=1;;Read...  ...
# 85494801   SOLD STC;;svg-camera=28;;svg-floorplan=1;;Read...  ...
# 85705701                            svg-camera=19;;Read more  ...
#
#           analyticsProperty.priceQualifier analyticsProperty.propertyId  \
# ids
# 124153820              Offers in Excess of                  124153820.0
# 120604136                             None                  120604136.0
# 124368626                      Guide Price                  124368626.0
# 120157577                             None                  120157577.0
# 120379235                             None                  120379235.0
# 122798015                             None                  122798015.0
# 85652838                       Guide Price                   85652838.0
# 122739626              Offers in Excess of                  122739626.0
# 120248726              Offers in Excess of                  120248726.0
# 123186293                      Guide Price                  123186293.0
# 118677035                             None                  118677035.0
# 120181052                             None                  120181052.0
# 114293234                      Guide Price                  114293234.0
# 124452128                      Guide Price                  124452128.0
# 120500297                             None                  120500297.0
# 123229436                      Guide Price                  123229436.0
# 120779345              Offers in Excess of                  120779345.0
# 122098883              Offers in Excess of                  122098883.0
# 122296673                             None                  122296673.0
# 84722637                              None                   84722637.0
# 123934121                      Guide Price                  123934121.0
# 121763024              Offers in Excess of                  121763024.0
# 114197282                      Guide Price                  114197282.0
# 85463622                              None                   85463622.0
# 85656135                       Guide Price                   85656135.0
# 122381537              Offers in Excess of                  122381537.0
# 122424989              Offers in Excess of                  122424989.0
# 116914793              Offers in Excess of                  116914793.0
# 121673984                             None                  121673984.0
# 118849808              Offers in Excess of                  118849808.0
# 120099290                      Offers Over                  120099290.0
# 122824235                 Shared ownership                  122824235.0
# 107258270                             None                  107258270.0
# 123258368                             None                  123258368.0
# 116542535                             None                  116542535.0
# 124180148                 Shared ownership                  124180148.0
# 115525946                 Shared ownership                  115525946.0
# 124584809                 Shared ownership                  124584809.0
# 124584860                 Shared ownership                  124584860.0
# 123524753                             None                  123524753.0
# 124584881                 Shared ownership                  124584881.0
# 123258365                             None                  123258365.0
# 124064723                      Guide Price                  124064723.0
# 124557605              Offers in Excess of                  124557605.0
# 124025066                      Guide Price                  124025066.0
# 124061165                      Guide Price                  124061165.0
# 122712446                             None                  122712446.0
# 122102135                      Guide Price                  122102135.0
# 85494801                       Guide Price                   85494801.0
# 85705701                       Guide Price                   85705701.0
#
#           analyticsProperty.propertySubType analyticsProperty.propertyType  \
# ids
# 124153820                        Town House                         Houses
# 120604136                    End of Terrace                         Houses
# 124368626                     Semi-Detached                         Houses
# 120157577                 Detached Bungalow                      Bungalows
# 120379235                     Semi-Detached                         Houses
# 122798015                        Maisonette             Flats / Apartments
# 85652838                               Flat             Flats / Apartments
# 122739626                         Apartment             Flats / Apartments
# 120248726                         Apartment             Flats / Apartments
# 123186293                         Apartment             Flats / Apartments
# 118677035                              Flat             Flats / Apartments
# 120181052                              Flat             Flats / Apartments
# 114293234                              Flat             Flats / Apartments
# 124452128                         Apartment             Flats / Apartments
# 120500297                         Apartment             Flats / Apartments
# 123229436                         Penthouse             Flats / Apartments
# 120779345                         Apartment             Flats / Apartments
# 122098883                              Flat             Flats / Apartments
# 122296673                              Flat             Flats / Apartments
# 84722637                               Flat             Flats / Apartments
# 123934121                         Apartment             Flats / Apartments
# 121763024                              Flat             Flats / Apartments
# 114197282                        Maisonette             Flats / Apartments
# 85463622                               Flat             Flats / Apartments
# 85656135                               Flat             Flats / Apartments
# 122381537                        Maisonette             Flats / Apartments
# 122424989                         Apartment             Flats / Apartments
# 116914793                         Apartment             Flats / Apartments
# 121673984                         Apartment             Flats / Apartments
# 118849808                         Apartment             Flats / Apartments
# 120099290                         Apartment             Flats / Apartments
# 122824235                         Apartment             Flats / Apartments
# 107258270                         Apartment             Flats / Apartments
# 123258368                              Flat             Flats / Apartments
# 116542535                              Flat             Flats / Apartments
# 124180148                         Apartment             Flats / Apartments
# 115525946                              Flat             Flats / Apartments
# 124584809                         Apartment             Flats / Apartments
# 124584860                         Apartment             Flats / Apartments
# 123524753                         Apartment             Flats / Apartments
# 124584881                         Apartment             Flats / Apartments
# 123258365                              Flat             Flats / Apartments
# 124064723                          Terraced                         Houses
# 124557605                    End of Terrace                         Houses
# 124025066                     Semi-Detached                         Houses
# 124061165                    End of Terrace                         Houses
# 122712446                     Semi-Detached                         Houses
# 122102135                     Semi-Detached                         Houses
# 85494801                      Semi-Detached                         Houses
# 85705701                      Semi-Detached                         Houses
#
#           analyticsProperty.retirement analyticsProperty.soldSTC  \
# ids
# 124153820                        False                     False
# 120604136                        False                      True
# 124368626                        False                     False
# 120157577                        False                     False
# 120379235                        False                      True
# 122798015                        False                     False
# 85652838                         False                     False
# 122739626                        False                     False
# 120248726                        False                      True
# 123186293                        False                     False
# 118677035                        False                     False
# 120181052                        False                     False
# 114293234                        False                     False
# 124452128                        False                     False
# 120500297                        False                     False
# 123229436                        False                     False
# 120779345                        False                     False
# 122098883                        False                     False
# 122296673                        False                     False
# 84722637                         False                      True
# 123934121                        False                     False
# 121763024                        False                     False
# 114197282                        False                     False
# 85463622                         False                     False
# 85656135                         False                     False
# 122381537                        False                      True
# 122424989                        False                     False
# 116914793                        False                      True
# 121673984                        False                     False
# 118849808                        False                     False
# 120099290                        False                     False
# 122824235                        False                      True
# 107258270                        False                     False
# 123258368                        False                     False
# 116542535                        False                     False
# 124180148                        False                     False
# 115525946                        False                      True
# 124584809                        False                     False
# 124584860                        False                     False
# 123524753                        False                     False
# 124584881                        False                     False
# 123258365                        False                     False
# 124064723                        False                     False
# 124557605                        False                     False
# 124025066                        False                     False
# 124061165                        False                     False
# 122712446                        False                      True
# 122102135                        False                      True
# 85494801                         False                      True
# 85705701                         False                     False
#
#           analyticsProperty.videoProvider analyticsProperty.viewType  \
# ids
# 124153820                        No Video                    Current
# 120604136                        No Video                    Current
# 124368626                        No Video                    Current
# 120157577                        No Video                    Current
# 120379235                        No Video                    Current
# 122798015                        No Video                    Current
# 85652838                         No Video                    Current
# 122739626                        No Video                    Current
# 120248726                        No Video                    Current
# 123186293                        No Video                    Current
# 118677035                        No Video                    Current
# 120181052                        No Video                    Current
# 114293234                        No Video                    Current
# 124452128                        No Video                    Current
# 120500297                        No Video                    Current
# 123229436                        No Video                    Current
# 120779345                        No Video                    Current
# 122098883                        No Video                    Current
# 122296673                        No Video                    Current
# 84722637                         No Video                    Current
# 123934121                        No Video                    Current
# 121763024                        No Video                    Current
# 114197282                        No Video                    Current
# 85463622                         No Video                    Current
# 85656135                    External Link                    Current
# 122381537                        No Video                    Current
# 122424989                        No Video                    Current
# 116914793                        No Video                    Current
# 121673984                   External Link                    Current
# 118849808                        No Video                    Current
# 120099290                        No Video                    Current
# 122824235                        No Video                    Current
# 107258270                        No Video                    Current
# 123258368                        No Video                    Current
# 116542535                        No Video                    Current
# 124180148                        No Video                    Current
# 115525946                        Embedded                    Current
# 124584809                        No Video                    Current
# 124584860                        No Video                    Current
# 123524753                        No Video                    Current
# 124584881                        No Video                    Current
# 123258365                        No Video                    Current
# 124064723                        No Video                    Current
# 124557605                        No Video                    Current
# 124025066                        No Video                    Current
# 124061165                        No Video                    Current
# 122712446                        No Video                    Current
# 122102135                        No Video                    Current
# 85494801                         No Video                    Current
# 85705701                         No Video                    Current
#
#            floorplan_count  borough_name
# ids
# 124153820              4.0    Hillingdon
# 120604136              4.0    Hillingdon
# 124368626              4.0    Hillingdon
# 120157577              4.0    Hillingdon
# 120379235              8.0    Hillingdon
# 122798015              9.0    Kensington
# 85652838               9.0    Kensington
# 122739626              4.0    Kensington
# 120248726              4.0    Kensington
# 123186293              4.0    Kensington
# 118677035              4.0    Kensington
# 120181052              9.0    Kensington
# 114293234              4.0    Kensington
# 124452128              4.0    Kensington
# 120500297              4.0      Hounslow
# 123229436              4.0      Hounslow
# 120779345              4.0     Islington
# 122098883              4.0     Islington
# 122296673              4.0     Islington
# 84722637               4.0     Islington
# 123934121              4.0     Islington
# 121763024              4.0     Islington
# 114197282              4.0     Islington
# 85463622               4.0     Islington
# 85656135               4.0     Islington
# 122381537              4.0     Islington
# 122424989              4.0     Islington
# 116914793              4.0     Islington
# 121673984              4.0     Islington
# 118849808              4.0     Islington
# 120099290              4.0      Hounslow
# 122824235              4.0      Hounslow
# 107258270              4.0      Hounslow
# 123258368              5.0      Hounslow
# 116542535              4.0      Hounslow
# 124180148              4.0      Hounslow
# 115525946              4.0      Hounslow
# 124584809              4.0      Hounslow
# 124584860              4.0      Hounslow
# 123524753              4.0      Hounslow
# 124584881              4.0      Hounslow
# 123258365              5.0      Hounslow
# 124064723              1.0      Havering
# 124557605              4.0      Havering
# 124025066              1.0      Havering
# 124061165              4.0      Havering
# 122712446              8.0      Havering
# 122102135              4.0      Havering
# 85494801               4.0      Havering
# 85705701               1.0      Havering
#
# [50 rows x 74 columns]

# %%
df_original.corr()
# Out:
#                                      Price  distance_to_any_train  bedrooms  \
# Price                             1.000000              -0.113363  0.449811
# distance_to_any_train            -0.113363               1.000000  0.141228
# bedrooms                          0.449811               0.141228  1.000000
# bathrooms                         0.268824               0.007910  0.335829
# bedrooms_model                    0.449811               0.141228  1.000000
# bathrooms_model                   0.268824               0.007910  0.335829
# location.latitude                 0.154405              -0.011473  0.139074
# analyticsBranch.branchId          0.000988              -0.042984  0.025078
# analyticsProperty.added           0.073851               0.000638  0.035073
# analyticsProperty.beds            0.449811               0.141228  1.000000
# analyticsProperty.floorplanCount  0.064589              -0.056622 -0.016931
# analyticsProperty.imageCount      0.185674              -0.007560  0.218708
# analyticsProperty.latitude        0.154405              -0.011473  0.139074
# analyticsProperty.longitude      -0.167132               0.014428  0.001475
# analyticsProperty.price           0.999835              -0.113240  0.450053
# analyticsProperty.propertyId      0.012413               0.010725  0.018591
# floorplan_count                   0.051944              -0.059374 -0.016147
#
#                                   bathrooms  bedrooms_model  bathrooms_model  \
# Price                              0.268824        0.449811         0.268824
# distance_to_any_train              0.007910        0.141228         0.007910
# bedrooms                           0.335829        1.000000         0.335829
# bathrooms                          1.000000        0.335829         1.000000
# bedrooms_model                     0.335829        1.000000         0.335829
# bathrooms_model                    1.000000        0.335829         1.000000
# location.latitude                  0.057773        0.139074         0.057773
# analyticsBranch.branchId           0.065757        0.025078         0.065757
# analyticsProperty.added           -0.016565        0.035073        -0.016565
# analyticsProperty.beds             0.335829        1.000000         0.335829
# analyticsProperty.floorplanCount   0.011812       -0.016931         0.011812
# analyticsProperty.imageCount       0.143206        0.218708         0.143206
# analyticsProperty.latitude         0.057773        0.139074         0.057773
# analyticsProperty.longitude       -0.078356        0.001475        -0.078356
# analyticsProperty.price            0.268961        0.450053         0.268961
# analyticsProperty.propertyId      -0.002162        0.018591        -0.002162
# floorplan_count                    0.013449       -0.016147         0.013449
#
#                                   location.latitude  analyticsBranch.branchId  \
# Price                                      0.154405                  0.000988
# distance_to_any_train                     -0.011473                 -0.042984
# bedrooms                                   0.139074                  0.025078
# bathrooms                                  0.057773                  0.065757
# bedrooms_model                             0.139074                  0.025078
# bathrooms_model                            0.057773                  0.065757
# location.latitude                          1.000000                 -0.000184
# analyticsBranch.branchId                  -0.000184                  1.000000
# analyticsProperty.added                    0.040620                  0.047546
# analyticsProperty.beds                     0.139074                  0.025078
# analyticsProperty.floorplanCount          -0.050034                  0.043812
# analyticsProperty.imageCount               0.138745                  0.060348
# analyticsProperty.latitude                 1.000000                 -0.000184
# analyticsProperty.longitude               -0.119734                  0.006221
# analyticsProperty.price                    0.154169                  0.000687
# analyticsProperty.propertyId               0.019704                  0.011757
# floorplan_count                           -0.045861                  0.036967
#
#                                   analyticsProperty.added  \
# Price                                            0.073851
# distance_to_any_train                            0.000638
# bedrooms                                         0.035073
# bathrooms                                       -0.016565
# bedrooms_model                                   0.035073
# bathrooms_model                                 -0.016565
# location.latitude                                0.040620
# analyticsBranch.branchId                         0.047546
# analyticsProperty.added                          1.000000
# analyticsProperty.beds                           0.035073
# analyticsProperty.floorplanCount                -0.033639
# analyticsProperty.imageCount                     0.055727
# analyticsProperty.latitude                       0.040620
# analyticsProperty.longitude                      0.019843
# analyticsProperty.price                          0.073622
# analyticsProperty.propertyId                     0.321996
# floorplan_count                                 -0.035871
#
#                                   analyticsProperty.beds  \
# Price                                           0.449811
# distance_to_any_train                           0.141228
# bedrooms                                        1.000000
# bathrooms                                       0.335829
# bedrooms_model                                  1.000000
# bathrooms_model                                 0.335829
# location.latitude                               0.139074
# analyticsBranch.branchId                        0.025078
# analyticsProperty.added                         0.035073
# analyticsProperty.beds                          1.000000
# analyticsProperty.floorplanCount               -0.016931
# analyticsProperty.imageCount                    0.218708
# analyticsProperty.latitude                      0.139074
# analyticsProperty.longitude                     0.001475
# analyticsProperty.price                         0.450053
# analyticsProperty.propertyId                    0.018591
# floorplan_count                                -0.016147
#
#                                   analyticsProperty.floorplanCount  \
# Price                                                     0.064589
# distance_to_any_train                                    -0.056622
# bedrooms                                                 -0.016931
# bathrooms                                                 0.011812
# bedrooms_model                                           -0.016931
# bathrooms_model                                           0.011812
# location.latitude                                        -0.050034
# analyticsBranch.branchId                                  0.043812
# analyticsProperty.added                                  -0.033639
# analyticsProperty.beds                                   -0.016931
# analyticsProperty.floorplanCount                          1.000000
# analyticsProperty.imageCount                             -0.000862
# analyticsProperty.latitude                               -0.050034
# analyticsProperty.longitude                              -0.050011
# analyticsProperty.price                                   0.064551
# analyticsProperty.propertyId                              0.001326
# floorplan_count                                           0.967935
#
#                                   analyticsProperty.imageCount  \
# Price                                                 0.185674
# distance_to_any_train                                -0.007560
# bedrooms                                              0.218708
# bathrooms                                             0.143206
# bedrooms_model                                        0.218708
# bathrooms_model                                       0.143206
# location.latitude                                     0.138745
# analyticsBranch.branchId                              0.060348
# analyticsProperty.added                               0.055727
# analyticsProperty.beds                                0.218708
# analyticsProperty.floorplanCount                     -0.000862
# analyticsProperty.imageCount                          1.000000
# analyticsProperty.latitude                            0.138745
# analyticsProperty.longitude                           0.194772
# analyticsProperty.price                               0.185829
# analyticsProperty.propertyId                          0.058933
# floorplan_count                                      -0.026849
#
#                                   analyticsProperty.latitude  \
# Price                                               0.154405
# distance_to_any_train                              -0.011473
# bedrooms                                            0.139074
# bathrooms                                           0.057773
# bedrooms_model                                      0.139074
# bathrooms_model                                     0.057773
# location.latitude                                   1.000000
# analyticsBranch.branchId                           -0.000184
# analyticsProperty.added                             0.040620
# analyticsProperty.beds                              0.139074
# analyticsProperty.floorplanCount                   -0.050034
# analyticsProperty.imageCount                        0.138745
# analyticsProperty.latitude                          1.000000
# analyticsProperty.longitude                        -0.119734
# analyticsProperty.price                             0.154169
# analyticsProperty.propertyId                        0.019704
# floorplan_count                                    -0.045861
#
#                                   analyticsProperty.longitude  \
# Price                                               -0.167132
# distance_to_any_train                                0.014428
# bedrooms                                             0.001475
# bathrooms                                           -0.078356
# bedrooms_model                                       0.001475
# bathrooms_model                                     -0.078356
# location.latitude                                   -0.119734
# analyticsBranch.branchId                             0.006221
# analyticsProperty.added                              0.019843
# analyticsProperty.beds                               0.001475
# analyticsProperty.floorplanCount                    -0.050011
# analyticsProperty.imageCount                         0.194772
# analyticsProperty.latitude                          -0.119734
# analyticsProperty.longitude                          1.000000
# analyticsProperty.price                             -0.167037
# analyticsProperty.propertyId                         0.004406
# floorplan_count                                     -0.046990
#
#                                   analyticsProperty.price  \
# Price                                            0.999835
# distance_to_any_train                           -0.113240
# bedrooms                                         0.450053
# bathrooms                                        0.268961
# bedrooms_model                                   0.450053
# bathrooms_model                                  0.268961
# location.latitude                                0.154169
# analyticsBranch.branchId                         0.000687
# analyticsProperty.added                          0.073622
# analyticsProperty.beds                           0.450053
# analyticsProperty.floorplanCount                 0.064551
# analyticsProperty.imageCount                     0.185829
# analyticsProperty.latitude                       0.154169
# analyticsProperty.longitude                     -0.167037
# analyticsProperty.price                          1.000000
# analyticsProperty.propertyId                     0.012392
# floorplan_count                                  0.051903
#
#                                   analyticsProperty.propertyId  \
# Price                                                 0.012413
# distance_to_any_train                                 0.010725
# bedrooms                                              0.018591
# bathrooms                                            -0.002162
# bedrooms_model                                        0.018591
# bathrooms_model                                      -0.002162
# location.latitude                                     0.019704
# analyticsBranch.branchId                              0.011757
# analyticsProperty.added                               0.321996
# analyticsProperty.beds                                0.018591
# analyticsProperty.floorplanCount                      0.001326
# analyticsProperty.imageCount                          0.058933
# analyticsProperty.latitude                            0.019704
# analyticsProperty.longitude                           0.004406
# analyticsProperty.price                               0.012392
# analyticsProperty.propertyId                          1.000000
# floorplan_count                                      -0.007403
#
#                                   floorplan_count
# Price                                    0.051944
# distance_to_any_train                   -0.059374
# bedrooms                                -0.016147
# bathrooms                                0.013449
# bedrooms_model                          -0.016147
# bathrooms_model                          0.013449
# location.latitude                       -0.045861
# analyticsBranch.branchId                 0.036967
# analyticsProperty.added                 -0.035871
# analyticsProperty.beds                  -0.016147
# analyticsProperty.floorplanCount         0.967935
# analyticsProperty.imageCount            -0.026849
# analyticsProperty.latitude              -0.045861
# analyticsProperty.longitude             -0.046990
# analyticsProperty.price                  0.051903
# analyticsProperty.propertyId            -0.007403
# floorplan_count                          1.000000
