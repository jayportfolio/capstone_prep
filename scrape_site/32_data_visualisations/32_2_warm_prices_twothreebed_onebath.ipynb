# %%
import os
import matplotlib.pyplot as plt

from globalfunction import vv

# %%
# Python ≥3.5 is required
import sys

assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn

assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# To plot pretty figures
% matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)


def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import os
import tarfile
import urllib.request

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"


def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()


fetch_housing_data()

# %%
# Download the California image
images_path = os.path.join(PROJECT_ROOT_DIR, "images", "end_to_end_project")
os.makedirs(images_path, exist_ok=True)
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
filename = "california.png"
print("Downloading", filename)
url = DOWNLOAD_ROOT + "images/end_to_end_project/" + filename
urllib.request.urlretrieve(url, os.path.join(images_path, filename))
# Out:
# Downloading california.png
# ('./images/end_to_end_project/california.png',
#  <http.client.HTTPMessage at 0x7f43616cd460>)

# %%
import pandas as pd


def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)


housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import matplotlib.image as mpimg

california_img = mpimg.imread(os.path.join(images_path, filename))
ax = housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(10, 7),
                  s=housing['population'] / 100, label="Population",
                  c="median_house_value", cmap=plt.get_cmap("jet"),
                  colorbar=False, alpha=0.4)
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = housing["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values / prices.max())
cbar.ax.set_yticklabels(["$%dk" % (round(v / 1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
save_fig("california_housing_prices_plot")
plt.show()
# Out:
# Saving figure california_housing_prices_plot

# %% [markdown]
# # New Attempt

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

party = pd.read_csv(vv.LISTING_JSON_MODEL_FILE)
party.head(1)
# Out:
# /tmp/ipykernel_5482/1228074493.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   party = pd.read_csv(vv.LISTING_JSON_MODEL_FILE)
#           id                                        keyFeatures  \
# 0  124126712  ['QUIET AREA SURROUNDED BY ELMSTEAD &amp; MARV...
#
#                                               images  \
# 0  [{'url': 'https://media.rightmove.co.uk/18k/17...
#
#                                           floorplans virtualTours  \
# 0  [{'url': 'https://media.rightmove.co.uk/18k/17...           []
#
#                                 industryAffiliations rooms nearestAirports  \
# 0  [{'name': 'Association of Residential Letting ...    []              []
#
#                                      nearestStations  showSchoolInfo  ...  \
# 0  [{'name': 'Elmstead Woods Station', 'types': [...            True  ...
#
#    sharedOwnership.rentPrice sharedOwnership.rentFrequency  \
# 0                        NaN                 not specified
#
#   livingCosts.councilTaxExempt livingCosts.councilTaxIncluded  \
# 0                        False                          False
#
#   livingCosts.annualGroundRent  livingCosts.groundRentReviewPeriodInYears  \
# 0                          NaN                                        NaN
#
#    livingCosts.groundRentPercentageIncrease livingCosts.annualServiceCharge  \
# 0                                       NaN                             NaN
#
#   livingCosts.councilTaxBand  livingCosts.domesticRates
# 0                        NaN                        NaN
#
# [1 rows x 88 columns]

# %%
#party['location.longitude'].value_counts()
#party[party['location.longitude'].isna()]
#party['location.longitude'].dtype

# %%
#party['location.latitude'].value_counts()
#party[party['location.latitude'].isna()]
#party[party['location.latitude'] > 50]
#party['location.latitude'].dtype
party = pd.read_csv(vv.LISTING_JSON_MODEL_FILE)
party = party.set_index('id')
# Out:
# /tmp/ipykernel_5482/1864684045.py:5: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   party = pd.read_csv(vv.LISTING_JSON_MODEL_FILE)

# %%
party['prices.primaryPrice']
# Out:
# id
# 124126712    £395,000
# 122078540    £100,000
# 123967277    £600,000
# 123772928    £830,000
# 85455351     £475,000
#                ...
# 122819864    £425,000
# 123604547    £425,000
# 121806869    £425,000
# 118504331    £425,000
# 120673127    £425,000
# Name: prices.primaryPrice, Length: 33332, dtype: object

# %%
party = party[~party.index.duplicated(keep='last')]
party = party[party["location.longitude"] < 10]
party["location.latitude"] = pd.to_numeric(party["location.latitude"], 'coerce').dropna().astype(float)
party["location.longitude"] = pd.to_numeric(party["location.longitude"], 'coerce').dropna().astype(float)

party["prices.primaryPrice"] = party['prices.primaryPrice'].str.extract('(\d+)') + "000"
party["prices.primaryPrice"] = pd.to_numeric(party["prices.primaryPrice"], 'coerce').dropna().astype(int)

# %%
party.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29511 entries, 124126712 to 120673127
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   keyFeatures                                         29511 non-null  object
#  1   images                                              29511 non-null  object
#  2   floorplans                                          29511 non-null  object
#  3   virtualTours                                        29511 non-null  object
#  4   industryAffiliations                                29511 non-null  object
#  5   rooms                                               29511 non-null  object
#  6   nearestAirports                                     29511 non-null  object
#  7   nearestStations                                     29511 non-null  object
#  8   showSchoolInfo                                      29511 non-null  bool
#  9   countryGuide                                        0 non-null      float64
#  10  channel                                             29511 non-null  object
#  11  sizings                                             29511 non-null  object
#  12  brochures                                           29511 non-null  object
#  13  epcGraphs                                           29511 non-null  object
#  14  bedrooms                                            28219 non-null  float64
#  15  bathrooms                                           27435 non-null  float64
#  16  transactionType                                     29511 non-null  object
#  17  tags                                                29511 non-null  object
#  18  feesApply                                           0 non-null      float64
#  19  lettings                                            0 non-null      float64
#  20  infoReelItems                                       29511 non-null  object
#  21  soldPropertyType                                    29511 non-null  object
#  22  auctionProvider                                     0 non-null      float64
#  23  propertySubType                                     29511 non-null  object
#  24  businessForSale                                     29511 non-null  bool
#  25  commercial                                          29511 non-null  bool
#  26  commercialUseClasses                                29511 non-null  object
#  27  affordableBuyingScheme                              0 non-null      float64
#  28  version                                             29511 non-null  object
#  29  date_scraped                                        29511 non-null  object
#  30  status.published                                    29511 non-null  bool
#  31  status.archived                                     29511 non-null  bool
#  32  text.description                                    29511 non-null  object
#  33  text.propertyPhrase                                 29511 non-null  object
#  34  text.shareText                                      29511 non-null  object
#  35  text.shareDescription                               29511 non-null  object
#  36  text.pageTitle                                      29511 non-null  object
#  37  text.shortDescription                               29511 non-null  object
#  38  prices.primaryPrice                                 29458 non-null  float64
#  39  prices.secondaryPrice                               0 non-null      float64
#  40  prices.displayPriceQualifier                        13304 non-null  object
#  41  prices.pricePerSqFt                                 4658 non-null   object
#  42  prices.message                                      1 non-null      object
#  43  prices.exchangeRate                                 0 non-null      float64
#  44  address.displayAddress                              29511 non-null  object
#  45  address.countryCode                                 29511 non-null  object
#  46  address.deliveryPointId                             19374 non-null  float64
#  47  address.ukCountry                                   29511 non-null  object
#  48  address.outcode                                     29511 non-null  object
#  49  address.incode                                      29511 non-null  object
#  50  location.latitude                                   29511 non-null  float64
#  51  location.longitude                                  29511 non-null  float64
#  52  location.circleRadiusOnMap                          29511 non-null  int64
#  53  location.zoomLevel                                  29511 non-null  int64
#  54  location.pinType                                    29511 non-null  object
#  55  location.showMap                                    29511 non-null  bool
#  56  propertyUrls.similarPropertiesUrl                   29511 non-null  object
#  57  propertyUrls.nearbySoldPropertiesUrl                29511 non-null  object
#  58  misInfo.branchId                                    29511 non-null  int64
#  59  misInfo.offerAdvertStampTypeId                      182 non-null    float64
#  60  misInfo.premiumDisplay                              29511 non-null  bool
#  61  misInfo.premiumDisplayStampId                       7502 non-null   float64
#  62  misInfo.brandPlus                                   29511 non-null  bool
#  63  misInfo.featuredProperty                            29511 non-null  bool
#  64  listingHistory.listingUpdateReason                  29509 non-null  object
#  65  broadband.broadbandCheckerUrl                       29510 non-null  object
#  66  contactInfo.contactMethod                           29511 non-null  object
#  67  contactInfo.telephoneNumbers.localNumber            29506 non-null  object
#  68  contactInfo.telephoneNumbers.internationalNumber    0 non-null      float64
#  69  contactInfo.telephoneNumbers.disclaimerText         0 non-null      float64
#  70  contactInfo.telephoneNumbers.disclaimerTitle        0 non-null      float64
#  71  contactInfo.telephoneNumbers.disclaimerDescription  0 non-null      float64
#  72  tenure.tenureType                                   27436 non-null  object
#  73  tenure.yearsRemainingOnLease                        1927 non-null   float64
#  74  tenure.message                                      2049 non-null   object
#  75  sharedOwnership.sharedOwnership                     29511 non-null  bool
#  76  sharedOwnership.ownershipPercentage                 79 non-null     float64
#  77  sharedOwnership.rentPrice                           73 non-null     float64
#  78  sharedOwnership.rentFrequency                       24978 non-null  object
#  79  livingCosts.councilTaxExempt                        29511 non-null  bool
#  80  livingCosts.councilTaxIncluded                      29511 non-null  bool
#  81  livingCosts.annualGroundRent                        228 non-null    float64
#  82  livingCosts.groundRentReviewPeriodInYears           48 non-null     float64
#  83  livingCosts.groundRentPercentageIncrease            33 non-null     float64
#  84  livingCosts.annualServiceCharge                     260 non-null    float64
#  85  livingCosts.councilTaxBand                          412 non-null    object
#  86  livingCosts.domesticRates                           8 non-null      float64
# dtypes: bool(12), float64(27), int64(3), object(45)
# memory usage: 17.4+ MB

# %%
party["location.longitude"]
# Out:
# id
# 124126712    0.043300
# 122078540   -0.010963
# 123772928    0.044054
# 85455351     0.103321
# 111715091   -0.064641
#                ...
# 122819864   -0.087210
# 123604547   -0.083399
# 121806869   -0.079964
# 118504331   -0.113830
# 120673127   -0.082720
# Name: location.longitude, Length: 29511, dtype: float64

# %%
party["location.latitude"]
# Out:
# id
# 124126712    51.424330
# 122078540    51.406952
# 123772928    51.375507
# 85455351     51.378744
# 111715091    51.406578
#                ...
# 122819864    51.378510
# 123604547    51.397132
# 121806869    51.412475
# 118504331    51.398450
# 120673127    51.384487
# Name: location.latitude, Length: 29511, dtype: float64

# %%
city_long_border = (-74.03, -73.75)
city_lat_border = (40.63, 40.85)
city_long_border = (party["location.longitude"].min(), party["location.longitude"].max())
city_lat_border = (party["location.latitude"].min(), party["location.latitude"].max())
print(city_long_border)
print(city_lat_border)
# ax = plt.scatter(party['Longitude'].values, party['Latitude'].values, color='blue', s=0.5, label='train', alpha=0.1)
ax = plt.scatter(party['location.longitude'].values, party['location.latitude'].values, color='blue', s=0.5, label='train', alpha=0.1)
ax.axes.set_title('Coordinates of the calls')
ax.figure.set_size_inches(6, 5)
plt.ylim(city_lat_border)
plt.xlim(city_long_border)
plt.show()
# Out:
# (-0.498166, 0.279356)
# (51.29832, 51.683185)

# %%
import matplotlib.image as mpimg

#california_img=mpimg.imread(os.path.join(images_path, filename))
ax = party.plot(kind="scatter", x="location.longitude", y="location.latitude", figsize=(10, 7),
                #s=housing['population']/100, label="Population",
                s=3, label="Population",
                c="prices.primaryPrice", cmap=plt.get_cmap("jet"),
                colorbar=False, alpha=0.4)
#plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5, cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = party["prices.primaryPrice"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values / prices.max())
cbar.ax.set_yticklabels(["$%dk" % (round(v / 1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)
save_fig("california_housing_prices_plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [35], in <cell line: 15>()
#      13 prices = party["prices.primaryPrice"]
#      14 tick_values = np.linspace(prices.min(), prices.max(), 11)
# ---> 15 cbar = plt.colorbar(ticks=tick_values / prices.max())
#      16 cbar.ax.set_yticklabels(["$%dk" % (round(v / 1000)) for v in tick_values], fontsize=14)
#      17 cbar.set_label('Median House Value', fontsize=16)
#
# File ~/Springboard/capstone_prework/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:2105, in colorbar(mappable, cax, ax, **kw)
#    2103     mappable = gci()
#    2104     if mappable is None:
# -> 2105         raise RuntimeError('No mappable was found to use for colorbar '
#    2106                            'creation. First define a mappable such as '
#    2107                            'an image (with imshow) or a contour set ('
#    2108                            'with contourf).')
#    2109 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2110 return ret
#
# RuntimeError: No mappable was found to use for colorbar creation. First define a mappable such as an image (with imshow) or a contour set (with contourf).
