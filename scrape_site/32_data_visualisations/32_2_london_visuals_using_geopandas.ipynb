# %%
import geopandas as gpd
import pandas as pd
import sys
sys.path.append('../../globalfunction')  # setting path
import globalfunction.vv as vv

# %%
# set the filepath and load in a shape
fp = "../datasets/statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp"
map_df = gpd.read_file(fp)

# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
#df = pd.read_csv('datasets/london-borough-profile.csv', header=0)
#df = pd.read_csv(vv.LISTING_COMBINED_FILE,encoding="utf-8")
df = vv.quick_data(remove_duplicates=True,numeric_values_only=False,HOW='listings_only')
df.head(20)
# Out:
# remove duplicates: 20286/29513/22089/23575 ==> 20286/20049/18445/19826
#                                                        Links  \
# ids
# 122711210  https://www.rightmove.co.uk/properties/1227112...
# 96540436   https://www.rightmove.co.uk/properties/9654043...
# 124458551  https://www.rightmove.co.uk/properties/1244585...
# 119253932  https://www.rightmove.co.uk/properties/1192539...
# 120485357  https://www.rightmove.co.uk/properties/1204853...
# 121102553  https://www.rightmove.co.uk/properties/1211025...
# 124368626  https://www.rightmove.co.uk/properties/1243686...
# 112919960  https://www.rightmove.co.uk/properties/1129199...
# 124352720  https://www.rightmove.co.uk/properties/1243527...
# 85489011   https://www.rightmove.co.uk/properties/8548901...
# 82843920   https://www.rightmove.co.uk/properties/8284392...
# 124028090  https://www.rightmove.co.uk/properties/1240280...
# 123319340  https://www.rightmove.co.uk/properties/1233193...
# 123209624  https://www.rightmove.co.uk/properties/1232096...
# 122161340  https://www.rightmove.co.uk/properties/1221613...
# 116514329  https://www.rightmove.co.uk/properties/1165143...
# 121776434  https://www.rightmove.co.uk/properties/1217764...
# 85708371   https://www.rightmove.co.uk/properties/8570837...
# 121425941  https://www.rightmove.co.uk/properties/1214259...
# 119098754  https://www.rightmove.co.uk/properties/1190987...
#
#                                                 Address  \
# ids
# 122711210                      Pole Hill Road, UXBRIDGE
# 96540436                       St. Johns Road, Uxbridge
# 124458551                           Compton Road, Hayes
# 119253932                Porters Way, West Drayton, UB7
# 120485357  Frithwood Avenue, Northwood, Hillingdon, HA6
# 121102553              Misbourne Road, Hillingdon, UB10
# 124368626          Grosvenor Crescent, Hillingdon, UB10
# 112919960                         Wyevale Close, Pinner
# 124352720          Denecroft Crescent, Hillingdon, UB10
# 85489011           Grosvenor Crescent, Hillingdon, UB10
# 82843920                     Victoria Close, Hayes, UB3
# 124028090       Carlyon Road, Hayes, Middlesex, UB4 0NS
# 123319340          Lyneham Walk, Pinner, Middlesex, HA5
# 123209624                         Long Lane, Hillingdon
# 122161340                             Dale Drive, Hayes
# 116514329                  Martin Close, Uxbridge, UB10
# 121776434                  Andover Close, Uxbridge, UB8
# 85708371               Balmoral Drive, North Hayes, UB4
# 121425941                                     Northwood
# 119098754     Hatherleigh Road, Ruislip, Middlesex, HA4
#
#                                        Description     Price       version  \
# ids
# 122711210              2 bedroom bungalow for sale  500000.0  v0021_300622
# 96540436    3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 124458551   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 119253932        3 bedroom terraced house for sale  525000.0  v0021_300622
# 120485357             2 bedroom apartment for sale  525000.0  v0021_300622
# 121102553   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 124368626   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 112919960        3 bedroom terraced house for sale  525000.0  v0021_300622
# 124352720  3 bedroom end of terrace house for sale  525000.0  v0021_300622
# 85489011         3 bedroom terraced house for sale  525000.0  v0021_300622
# 82843920      4 bedroom detached bungalow for sale  525000.0  v0021_300622
# 124028090        3 bedroom terraced house for sale  525000.0  v0021_300622
# 123319340        3 bedroom terraced house for sale  525000.0  v0021_300622
# 123209624   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 122161340   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 116514329        3 bedroom terraced house for sale  525000.0  v0021_300622
# 121776434   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 85708371    3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 121425941  3 bedroom end of terrace house for sale  525000.0  v0021_300622
# 119098754        2 bedroom terraced house for sale  525000.0  v0021_300622
#
#                              borough  \
# ids
# 122711210  ('Hillingdon', '5E93959')
# 96540436   ('Hillingdon', '5E93959')
# 124458551  ('Hillingdon', '5E93959')
# 119253932  ('Hillingdon', '5E93959')
# 120485357  ('Hillingdon', '5E93959')
# 121102553  ('Hillingdon', '5E93959')
# 124368626  ('Hillingdon', '5E93959')
# 112919960  ('Hillingdon', '5E93959')
# 124352720  ('Hillingdon', '5E93959')
# 85489011   ('Hillingdon', '5E93959')
# 82843920   ('Hillingdon', '5E93959')
# 124028090  ('Hillingdon', '5E93959')
# 123319340  ('Hillingdon', '5E93959')
# 123209624  ('Hillingdon', '5E93959')
# 122161340  ('Hillingdon', '5E93959')
# 116514329  ('Hillingdon', '5E93959')
# 121776434  ('Hillingdon', '5E93959')
# 85708371   ('Hillingdon', '5E93959')
# 121425941  ('Hillingdon', '5E93959')
# 119098754  ('Hillingdon', '5E93959')
#
#                                             referencing_link  \
# ids
# 122711210  https://www.rightmove.co.uk/property-for-sale/...
# 96540436   https://www.rightmove.co.uk/property-for-sale/...
# 124458551  https://www.rightmove.co.uk/property-for-sale/...
# 119253932  https://www.rightmove.co.uk/property-for-sale/...
# 120485357  https://www.rightmove.co.uk/property-for-sale/...
# 121102553  https://www.rightmove.co.uk/property-for-sale/...
# 124368626  https://www.rightmove.co.uk/property-for-sale/...
# 112919960  https://www.rightmove.co.uk/property-for-sale/...
# 124352720  https://www.rightmove.co.uk/property-for-sale/...
# 85489011   https://www.rightmove.co.uk/property-for-sale/...
# 82843920   https://www.rightmove.co.uk/property-for-sale/...
# 124028090  https://www.rightmove.co.uk/property-for-sale/...
# 123319340  https://www.rightmove.co.uk/property-for-sale/...
# 123209624  https://www.rightmove.co.uk/property-for-sale/...
# 122161340  https://www.rightmove.co.uk/property-for-sale/...
# 116514329  https://www.rightmove.co.uk/property-for-sale/...
# 121776434  https://www.rightmove.co.uk/property-for-sale/...
# 85708371   https://www.rightmove.co.uk/property-for-sale/...
# 121425941  https://www.rightmove.co.uk/property-for-sale/...
# 119098754  https://www.rightmove.co.uk/property-for-sale/...
#
#                                                     add_info  \
# ids
# 122711210        Added on 22/04/2022 by haart, Hayes (Middx)
# 96540436    Added on 09/05/2022 by Allday & Miller, Uxbridge
# 124458551  Added on 29/06/2022 by Roberts Hunt & Co, Bedfont
# 119253932            Reduced on 25/02/2022 by Strike, London
# 120485357  Added on 28/02/2022 by Gibbs Gillespie, Northw...
# 121102553       Reduced on 13/04/2022 by Coopers, Hillingdon
# 124368626         Added on 27/06/2022 by Coopers, Hillingdon
# 112919960            Added on 03/09/2021 by Coopers, Ruislip
# 124352720         Added on 27/06/2022 by Coopers, Hillingdon
# 85489011          Added on 08/06/2022 by Coopers, Hillingdon
# 82843920   Reduced on 17/02/2022 by Purplebricks, coverin...
# 124028090              Added on 17/06/2022 by Hunters, Hayes
# 123319340  Added on 13/05/2022 by Gibbs Gillespie, Ruisli...
# 123209624  Added on 10/05/2022 by Andrews Residential, Hi...
# 122161340          Added on 08/04/2022 by B Simmons, Langley
# 116514329  Added on 18/11/2021 by Coopers, Uxbridge - Hig...
# 121776434  Added on 31/03/2022 by Coopers, Uxbridge - Hig...
# 85708371          Added on 14/06/2022 by Coopers, Hillingdon
# 121425941  Added on 23/03/2022 by Robsons, Northwood - Sales
# 119098754  Added on 24/01/2022 by Gibbs Gillespie, Ruisli...
#
#                   date_scraped
# ids
# 122711210  2022-07-03 17:02:04
# 96540436   2022-07-03 17:02:05
# 124458551  2022-07-03 17:02:05
# 119253932  2022-07-03 17:02:05
# 120485357  2022-07-03 17:02:05
# 121102553  2022-07-03 17:02:05
# 124368626  2022-07-03 17:02:05
# 112919960  2022-07-03 17:02:05
# 124352720  2022-07-03 17:02:06
# 85489011   2022-07-03 17:02:06
# 82843920   2022-07-03 17:02:06
# 124028090  2022-07-03 17:02:06
# 123319340  2022-07-03 17:02:06
# 123209624  2022-07-03 17:02:06
# 122161340  2022-07-03 17:02:06
# 116514329  2022-07-03 17:02:07
# 121776434  2022-07-03 17:02:07
# 85708371   2022-07-03 17:02:07
# 121425941  2022-07-03 17:02:07
# 119098754  2022-07-03 17:02:07

# %%
df['Price'] = pd.to_numeric(df['Price'], 'coerce').dropna().astype(int)
df = df[df["Price"] <= 600000]
print(df.shape)
df.head()
# Out:
# (18555, 9)
#                                                        Links  \
# ids
# 122711210  https://www.rightmove.co.uk/properties/1227112...
# 96540436   https://www.rightmove.co.uk/properties/9654043...
# 124458551  https://www.rightmove.co.uk/properties/1244585...
# 119253932  https://www.rightmove.co.uk/properties/1192539...
# 120485357  https://www.rightmove.co.uk/properties/1204853...
#
#                                                 Address  \
# ids
# 122711210                      Pole Hill Road, UXBRIDGE
# 96540436                       St. Johns Road, Uxbridge
# 124458551                           Compton Road, Hayes
# 119253932                Porters Way, West Drayton, UB7
# 120485357  Frithwood Avenue, Northwood, Hillingdon, HA6
#
#                                       Description     Price       version  \
# ids
# 122711210             2 bedroom bungalow for sale  500000.0  v0021_300622
# 96540436   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 124458551  3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 119253932       3 bedroom terraced house for sale  525000.0  v0021_300622
# 120485357            2 bedroom apartment for sale  525000.0  v0021_300622
#
#                              borough  \
# ids
# 122711210  ('Hillingdon', '5E93959')
# 96540436   ('Hillingdon', '5E93959')
# 124458551  ('Hillingdon', '5E93959')
# 119253932  ('Hillingdon', '5E93959')
# 120485357  ('Hillingdon', '5E93959')
#
#                                             referencing_link  \
# ids
# 122711210  https://www.rightmove.co.uk/property-for-sale/...
# 96540436   https://www.rightmove.co.uk/property-for-sale/...
# 124458551  https://www.rightmove.co.uk/property-for-sale/...
# 119253932  https://www.rightmove.co.uk/property-for-sale/...
# 120485357  https://www.rightmove.co.uk/property-for-sale/...
#
#                                                     add_info  \
# ids
# 122711210        Added on 22/04/2022 by haart, Hayes (Middx)
# 96540436    Added on 09/05/2022 by Allday & Miller, Uxbridge
# 124458551  Added on 29/06/2022 by Roberts Hunt & Co, Bedfont
# 119253932            Reduced on 25/02/2022 by Strike, London
# 120485357  Added on 28/02/2022 by Gibbs Gillespie, Northw...
#
#                   date_scraped
# ids
# 122711210  2022-07-03 17:02:04
# 96540436   2022-07-03 17:02:05
# 124458551  2022-07-03 17:02:05
# 119253932  2022-07-03 17:02:05
# 120485357  2022-07-03 17:02:05

# %%
df.columns
# Out:
# Index(['Links', 'Address', 'Description', 'Price', 'version', 'borough',
#        'referencing_link', 'add_info', 'date_scraped'],
#       dtype='object')

# %%
# those are really terrible column names. let's rename them to something simpler
score = df.rename(index=str, columns={"Station_Prox": "closeness_to_station",'bedrooms_model':'bedrooms','bathrooms_model':'bathrooms','tenure.tenureType':'tenureType'}
                                      )
score.head()
# Out:
#                                                        Links  \
# ids
# 122711210  https://www.rightmove.co.uk/properties/1227112...
# 96540436   https://www.rightmove.co.uk/properties/9654043...
# 124458551  https://www.rightmove.co.uk/properties/1244585...
# 119253932  https://www.rightmove.co.uk/properties/1192539...
# 120485357  https://www.rightmove.co.uk/properties/1204853...
#
#                                                 Address  \
# ids
# 122711210                      Pole Hill Road, UXBRIDGE
# 96540436                       St. Johns Road, Uxbridge
# 124458551                           Compton Road, Hayes
# 119253932                Porters Way, West Drayton, UB7
# 120485357  Frithwood Avenue, Northwood, Hillingdon, HA6
#
#                                       Description     Price       version  \
# ids
# 122711210             2 bedroom bungalow for sale  500000.0  v0021_300622
# 96540436   3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 124458551  3 bedroom semi-detached house for sale  525000.0  v0021_300622
# 119253932       3 bedroom terraced house for sale  525000.0  v0021_300622
# 120485357            2 bedroom apartment for sale  525000.0  v0021_300622
#
#                              borough  \
# ids
# 122711210  ('Hillingdon', '5E93959')
# 96540436   ('Hillingdon', '5E93959')
# 124458551  ('Hillingdon', '5E93959')
# 119253932  ('Hillingdon', '5E93959')
# 120485357  ('Hillingdon', '5E93959')
#
#                                             referencing_link  \
# ids
# 122711210  https://www.rightmove.co.uk/property-for-sale/...
# 96540436   https://www.rightmove.co.uk/property-for-sale/...
# 124458551  https://www.rightmove.co.uk/property-for-sale/...
# 119253932  https://www.rightmove.co.uk/property-for-sale/...
# 120485357  https://www.rightmove.co.uk/property-for-sale/...
#
#                                                     add_info  \
# ids
# 122711210        Added on 22/04/2022 by haart, Hayes (Middx)
# 96540436    Added on 09/05/2022 by Allday & Miller, Uxbridge
# 124458551  Added on 29/06/2022 by Roberts Hunt & Co, Bedfont
# 119253932            Reduced on 25/02/2022 by Strike, London
# 120485357  Added on 28/02/2022 by Gibbs Gillespie, Northw...
#
#                   date_scraped
# ids
# 122711210  2022-07-03 17:02:04
# 96540436   2022-07-03 17:02:05
# 124458551  2022-07-03 17:02:05
# 119253932  2022-07-03 17:02:05
# 120485357  2022-07-03 17:02:05

# %%
score['Price'] = pd.to_numeric(score['Price'], 'coerce').fillna(-1).astype(int)

score['borough_name'] = score["borough"].str.extract("'([a-zA-Z]+)'")
borough_property = score.groupby(['borough_name']).agg(mean_price=('Price',"mean"), median_price=('Price',"median"), total_properties=('Price','count'))
#borough_property = borough_property.reset_index()
borough_property
# Out:
#                  mean_price  median_price  total_properties
# borough_name
# Barnet        365998.071249      350000.0              1193
# Brent         596104.125000      600000.0               120
# Bromley       327506.220736      325000.0               897
# Camden        401529.713115      450000.0               244
# Croydon       251414.526786      225000.0               448
# Ealing        418888.276328      430000.0              2222
# Enfield       388060.317511      390000.0              1559
# Greenwich     321924.887771      325000.0              1292
# Hackney       439933.404945      450000.0              1173
# Haringey      421043.870356      439000.0              1265
# Harrow        422311.926483      425000.0              1197
# Havering      367500.163685      375000.0              1509
# Hillingdon    356230.816550      325000.0              1281
# Hounslow      261872.712477      270000.0               553
# Islington     426479.314050      365000.0               242
# Merton        420816.418349      425000.0               545
# Sutton        316628.623446      300000.0               563
# Wandsworth    441469.965517      450000.0               174

# %%
# join the geodataframe with the cleaned up csv dataframe
#merged = map_df.set_index('NAME').join(borough_property.set_index('borough_name'))
merged = map_df.set_index('NAME').join(borough_property)

print(merged.shape)
merged
# Out:
# (33, 10)
#                          GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# NAME
# Kingston upon Thames    E09000021   3726.117       0.000         F     None
# Croydon                 E09000008   8649.441       0.000         F     None
# Bromley                 E09000006  15013.487       0.000         F     None
# Hounslow                E09000018   5658.541      60.755         F     None
# Ealing                  E09000009   5554.428       0.000         F     None
# Havering                E09000016  11445.735     210.763         F     None
# Hillingdon              E09000017  11570.063       0.000         F     None
# Harrow                  E09000015   5046.330       0.000         F     None
# Brent                   E09000005   4323.270       0.000         F     None
# Barnet                  E09000003   8674.837       0.000         F     None
# Lambeth                 E09000022   2724.940      43.927         T     None
# Southwark               E09000028   2991.340     105.139         T     None
# Lewisham                E09000023   3531.706      16.795         T     None
# Greenwich               E09000011   5044.190     310.785         F     None
# Bexley                  E09000004   6428.649     370.619         F     None
# Enfield                 E09000010   8220.025       0.000         F     None
# Waltham Forest          E09000031   3880.793       0.000         F     None
# Redbridge               E09000026   5644.225       2.300         F     None
# Sutton                  E09000029   4384.698       0.000         F     None
# Richmond upon Thames    E09000027   5876.111     135.443         F     None
# Merton                  E09000024   3762.466       0.000         F     None
# Wandsworth              E09000032   3522.022      95.600         T     None
# Hammersmith and Fulham  E09000013   1715.409      75.648         T     None
# Kensington and Chelsea  E09000020   1238.379      25.994         T     None
# Westminster             E09000033   2203.005      54.308         T     None
# Camden                  E09000007   2178.932       0.000         T     None
# Tower Hamlets           E09000030   2157.501     179.707         T     None
# Islington               E09000019   1485.664       0.000         T     None
# Hackney                 E09000012   1904.902       0.000         T     None
# Haringey                E09000014   2959.837       0.000         T     None
# Newham                  E09000025   3857.806     237.637         T     None
# Barking and Dagenham    E09000002   3779.934     169.150         F     None
# City of London          E09000001    314.942      24.546         T     None
#
#                        SUB_2006  \
# NAME
# Kingston upon Thames       None
# Croydon                    None
# Bromley                    None
# Hounslow                   None
# Ealing                     None
# Havering                   None
# Hillingdon                 None
# Harrow                     None
# Brent                      None
# Barnet                     None
# Lambeth                    None
# Southwark                  None
# Lewisham                   None
# Greenwich                  None
# Bexley                     None
# Enfield                    None
# Waltham Forest             None
# Redbridge                  None
# Sutton                     None
# Richmond upon Thames       None
# Merton                     None
# Wandsworth                 None
# Hammersmith and Fulham     None
# Kensington and Chelsea     None
# Westminster                None
# Camden                     None
# Tower Hamlets              None
# Islington                  None
# Hackney                    None
# Haringey                   None
# Newham                     None
# Barking and Dagenham       None
# City of London             None
#
#                                                                  geometry  \
# NAME
# Kingston upon Thames    POLYGON ((516401.600 160201.800, 516407.300 16...
# Croydon                 POLYGON ((535009.200 159504.700, 535005.500 15...
# Bromley                 POLYGON ((540373.600 157530.400, 540361.200 15...
# Hounslow                POLYGON ((521975.800 178100.000, 521967.700 17...
# Ealing                  POLYGON ((510253.500 182881.600, 510249.900 18...
# Havering                POLYGON ((549893.900 181459.800, 549894.600 18...
# Hillingdon              POLYGON ((510599.800 191689.500, 510615.200 19...
# Harrow                  POLYGON ((510599.800 191689.500, 510660.000 19...
# Brent                   POLYGON ((525201.000 182512.600, 525181.500 18...
# Barnet                  POLYGON ((524579.900 198355.200, 524594.300 19...
# Lambeth                 POLYGON ((530046.800 177893.400, 530048.400 17...
# Southwark               POLYGON ((531335.600 180529.500, 531337.700 18...
# Lewisham                POLYGON ((536691.000 178958.600, 536691.900 17...
# Greenwich               MULTIPOLYGON (((537238.700 178137.700, 537242....
# Bexley                  POLYGON ((547226.200 181299.300, 547320.900 18...
# Enfield                 POLYGON ((531023.500 200933.600, 531039.900 20...
# Waltham Forest          POLYGON ((539923.100 191863.100, 539928.100 19...
# Redbridge               POLYGON ((543595.500 184832.800, 543577.100 18...
# Sutton                  POLYGON ((528552.300 159658.100, 528399.700 15...
# Richmond upon Thames    POLYGON ((516677.500 175383.800, 516678.600 17...
# Merton                  POLYGON ((529906.200 167417.300, 529902.200 16...
# Wandsworth              POLYGON ((523489.600 176224.800, 523500.600 17...
# Hammersmith and Fulham  POLYGON ((521975.800 178100.000, 521973.000 17...
# Kensington and Chelsea  POLYGON ((526219.700 176948.000, 526208.800 17...
# Westminster             POLYGON ((528549.500 177903.800, 528542.600 17...
# Camden                  POLYGON ((528840.200 187217.800, 528834.600 18...
# Tower Hamlets           POLYGON ((533387.600 180516.400, 533389.800 18...
# Islington               POLYGON ((529153.600 185861.400, 529144.800 18...
# Hackney                 POLYGON ((531928.400 187801.500, 531935.700 18...
# Haringey                POLYGON ((531928.400 187801.500, 531919.200 18...
# Newham                  MULTIPOLYGON (((544065.000 183254.100, 544062....
# Barking and Dagenham    MULTIPOLYGON (((543905.400 183199.100, 543905....
# City of London          POLYGON ((531145.100 180782.100, 531143.800 18...
#
#                            mean_price  median_price  total_properties
# NAME
# Kingston upon Thames              NaN           NaN               NaN
# Croydon                 251414.526786      225000.0             448.0
# Bromley                 327506.220736      325000.0             897.0
# Hounslow                261872.712477      270000.0             553.0
# Ealing                  418888.276328      430000.0            2222.0
# Havering                367500.163685      375000.0            1509.0
# Hillingdon              356230.816550      325000.0            1281.0
# Harrow                  422311.926483      425000.0            1197.0
# Brent                   596104.125000      600000.0             120.0
# Barnet                  365998.071249      350000.0            1193.0
# Lambeth                           NaN           NaN               NaN
# Southwark                         NaN           NaN               NaN
# Lewisham                          NaN           NaN               NaN
# Greenwich               321924.887771      325000.0            1292.0
# Bexley                            NaN           NaN               NaN
# Enfield                 388060.317511      390000.0            1559.0
# Waltham Forest                    NaN           NaN               NaN
# Redbridge                         NaN           NaN               NaN
# Sutton                  316628.623446      300000.0             563.0
# Richmond upon Thames              NaN           NaN               NaN
# Merton                  420816.418349      425000.0             545.0
# Wandsworth              441469.965517      450000.0             174.0
# Hammersmith and Fulham            NaN           NaN               NaN
# Kensington and Chelsea            NaN           NaN               NaN
# Westminster                       NaN           NaN               NaN
# Camden                  401529.713115      450000.0             244.0
# Tower Hamlets                     NaN           NaN               NaN
# Islington               426479.314050      365000.0             242.0
# Hackney                 439933.404945      450000.0            1173.0
# Haringey                421043.870356      439000.0            1265.0
# Newham                            NaN           NaN               NaN
# Barking and Dagenham              NaN           NaN               NaN
# City of London                    NaN           NaN               NaN

# %%
from matplotlib import pyplot as plt

# set a variable that will call whatever column we want to visualise on the map
variable = 'median_price'

# set the range for the choropleth
#vmin, vmax = 120, 220
vmin, vmax = merged[variable].min(), merged[variable].max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# Now we can customise and add annotations

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Median Property Price in London', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})

# create an annotation for the  data source
ax.annotate('Source: London Datastore, 2014',
           xy=(0.1, .08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
fig.savefig('testmap_median_price.png', dpi=300)

# %%
from matplotlib import pyplot as plt

# set a variable that will call whatever column we want to visualise on the map
variable = 'mean_price'

# set the range for the choropleth
#vmin, vmax = 120, 220
vmin, vmax = merged[variable].min(), merged[variable].max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# Now we can customise and add annotations

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Mean Property Price in London', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})

# create an annotation for the  data source
ax.annotate('Source: London Datastore, 2014',
           xy=(0.1, .08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
fig.savefig('testmap_mean_price.png', dpi=300)

# %%
from matplotlib import pyplot as plt

# set a variable that will call whatever column we want to visualise on the map
variable = 'total_properties'

# set the range for the choropleth
#vmin, vmax = 120, 220
vmin, vmax = merged[variable].min(), merged[variable].max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))

# create map
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')

# Now we can customise and add annotations

# remove the axis
ax.axis('off')

# add a title
ax.set_title('Number of Properties available for sale in London', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})

# create an annotation for the  data source
ax.annotate('Source: London Datastore, 2014',
           xy=(0.1, .08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)

# this will save the figure as a high-res png. you can also save as svg
fig.savefig('testmap_total_properties.png', dpi=300)
